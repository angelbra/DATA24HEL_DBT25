# %% [markdown]
# # Dokumentdatabas - Northwind

# %%
import json
import pandas as pd
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
PWD = open("../../../mongodb.pwd", "r").read().strip()

uri = f"mongodb+srv://linusrundbergstreuli:{PWD}@koksgladje.f2fmq.mongodb.net/?retryWrites=true&w=majority&appName=Koksgladje"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
database = client["Northwind"]
collection = database["Orders"]

# %% [markdown]
# ## Orders

# %% [markdown]
# Våra två dataset, `Orders`och `OrderDetails`, kommer i olika format. Det är inga problem, pandas kan ju läsa både `csv` och `JSON`.
#
# Vi skapar två `DataFrames`; `orders`och `order_details`.

# %%
orders = pd.read_csv("orders.csv", index_col=False)
order_details = pd.read_json("order_details.json")

# %%
orders.head()
# Out:
#    OrderID            OrderDate         RequiredDate          ShippedDate  \
# 0    10248  1996-07-04 00:00:00  1996-08-01 00:00:00  1996-07-16 00:00:00
# 1    10249  1996-07-05 00:00:00  1996-08-16 00:00:00  1996-07-10 00:00:00
# 2    10250  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-12 00:00:00
# 3    10251  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-15 00:00:00
# 4    10252  1996-07-09 00:00:00  1996-08-06 00:00:00  1996-07-11 00:00:00
#
#                     ShipName ShipCountry ShipRegion           ShipAddress  \
# 0  Vins et alcools Chevalier      France        NaN    59 rue de l'Abbaye
# 1         Toms Spezialitäten     Germany        NaN         Luisenstr. 48
# 2              Hanari Carnes      Brazil         RJ       Rua do Paço, 67
# 3       Victuailles en stock      France        NaN    2, rue du Commerce
# 4           Suprêmes délices     Belgium        NaN  Boulevard Tirou, 255
#
#   ShipPostalCode        ShipCity
# 0          51100           Reims
# 1          44087         Münster
# 2      05454-876  Rio de Janeiro
# 3          69004            Lyon
# 4         B-6000       Charleroi

# %%
order_details.head()
# Out:
#    OrderID  ProductID  Quantity             UnitPrice  Discount
# 0    10248         11        12                 14 kr       0.0
# 1    10248         42        10  9.800000000000001 kr       0.0
# 2    10248         72         5               34.8 kr       0.0
# 3    10249         14         9               18.6 kr       0.0
# 4    10249         51        40               42.4 kr       0.0

# %% [markdown]
# Vi behöver tvätta datan lite innan vi läser in den i databasen.

# %%
order_details["UnitPrice"] = order_details.UnitPrice.str.replace(" kr", "").astype(float)

# %%
order_details.head()
# Out:
#    OrderID  ProductID  Quantity  UnitPrice  Discount
# 0    10248         11        12       14.0       0.0
# 1    10248         42        10        9.8       0.0
# 2    10248         72         5       34.8       0.0
# 3    10249         14         9       18.6       0.0
# 4    10249         51        40       42.4       0.0

# %%
orders.head()
# Out:
#    OrderID            OrderDate         RequiredDate          ShippedDate  \
# 0    10248  1996-07-04 00:00:00  1996-08-01 00:00:00  1996-07-16 00:00:00
# 1    10249  1996-07-05 00:00:00  1996-08-16 00:00:00  1996-07-10 00:00:00
# 2    10250  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-12 00:00:00
# 3    10251  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-15 00:00:00
# 4    10252  1996-07-09 00:00:00  1996-08-06 00:00:00  1996-07-11 00:00:00
#
#                     ShipName ShipCountry ShipRegion           ShipAddress  \
# 0  Vins et alcools Chevalier      France        NaN    59 rue de l'Abbaye
# 1         Toms Spezialitäten     Germany        NaN         Luisenstr. 48
# 2              Hanari Carnes      Brazil         RJ       Rua do Paço, 67
# 3       Victuailles en stock      France        NaN    2, rue du Commerce
# 4           Suprêmes délices     Belgium        NaN  Boulevard Tirou, 255
#
#   ShipPostalCode        ShipCity
# 0          51100           Reims
# 1          44087         Münster
# 2      05454-876  Rio de Janeiro
# 3          69004            Lyon
# 4         B-6000       Charleroi

# %% [markdown]
# För att läsa in datan i MongoDB vill vi ha den som dokument i `JSON`-format. Varje `Order` ska vara ett eget dokument, som innehåller de `OrderDetails` som hör till `Order`:n som nästlade dokument.

# %%
orders["OrderDetails"] = \
orders.apply(
    lambda x: json.loads(
        order_details.query(f"OrderID == {x.OrderID}")
        .to_json(orient="records")), 
    axis=1)

# %% [markdown]
# Koden ovan är kanske en smula komplicerad. Låt oss bryta ner den!
#
# 1. Vi vill skapa en ny kolumn i `orders` som heter `OrderDetails`. Den ska innehålla JSON-formaterade objekt som innehåller datan från alla `OrderDetails` med samma `OrderID` som raden. `\` gör att vi får fortsätta koden på nästa rad.
# 2. `orders.apply()` tar en funktion vi anger och kör den på varje rad i `orders`.
# 3. Funktionen vi anger är en `lambda`-funktion. `x` kommer att vara varje rad i `orders`, uppifrån och ned, och själva funktionen returnerar resultatet av `json.loads()`, alltså ett JSON-formaterat objekt.
# 4. Vad ska vårt JSON-formaterade objekt bestå av? Jo, vi gör en *query* på `order_details` och matchar värdet i `OrderID`-kolumnerna mellan våra `DataFrame`:s.
# 5. `query`-metoden returnerar en `DataFrame` som vi omvandlar till JSON och använder *records*-orienteringen, som passar bäst för dokumentdatabaser.
# 6. `axis=1` anger att vi vill att vår `apply` ska gå på radnivå så att vi har tillgång till värdena i `OrderID`-kolumnen.
#
# Vi kan se ut `orders["OrderDetails"]` ser ut!

# %%
orders["OrderDetails"]
# Out:
# 0      [{'OrderID': 10248, 'ProductID': 11, 'Quantity...
# 1      [{'OrderID': 10249, 'ProductID': 14, 'Quantity...
# 2      [{'OrderID': 10250, 'ProductID': 41, 'Quantity...
# 3      [{'OrderID': 10251, 'ProductID': 22, 'Quantity...
# 4      [{'OrderID': 10252, 'ProductID': 20, 'Quantity...
#                              ...
# 825    [{'OrderID': 11073, 'ProductID': 11, 'Quantity...
# 826    [{'OrderID': 11074, 'ProductID': 16, 'Quantity...
# 827    [{'OrderID': 11075, 'ProductID': 2, 'Quantity'...
# 828    [{'OrderID': 11076, 'ProductID': 6, 'Quantity'...
# 829    [{'OrderID': 11077, 'ProductID': 2, 'Quantity'...
# Name: OrderDetails, Length: 830, dtype: object

# %% [markdown]
# Det är en lista med *dictionaries* som innehåller våra `OrderDetails` för varje `Order`.
#
# ...och hela `orders` ser nu ut såhär:

# %%
orders.head()
# Out:
#    OrderID            OrderDate         RequiredDate          ShippedDate  \
# 0    10248  1996-07-04 00:00:00  1996-08-01 00:00:00  1996-07-16 00:00:00
# 1    10249  1996-07-05 00:00:00  1996-08-16 00:00:00  1996-07-10 00:00:00
# 2    10250  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-12 00:00:00
# 3    10251  1996-07-08 00:00:00  1996-08-05 00:00:00  1996-07-15 00:00:00
# 4    10252  1996-07-09 00:00:00  1996-08-06 00:00:00  1996-07-11 00:00:00
#
#                     ShipName ShipCountry ShipRegion           ShipAddress  \
# 0  Vins et alcools Chevalier      France        NaN    59 rue de l'Abbaye
# 1         Toms Spezialitäten     Germany        NaN         Luisenstr. 48
# 2              Hanari Carnes      Brazil         RJ       Rua do Paço, 67
# 3       Victuailles en stock      France        NaN    2, rue du Commerce
# 4           Suprêmes délices     Belgium        NaN  Boulevard Tirou, 255
#
#   ShipPostalCode        ShipCity  \
# 0          51100           Reims
# 1          44087         Münster
# 2      05454-876  Rio de Janeiro
# 3          69004            Lyon
# 4         B-6000       Charleroi
#
#                                         OrderDetails
# 0  [{'OrderID': 10248, 'ProductID': 11, 'Quantity...
# 1  [{'OrderID': 10249, 'ProductID': 14, 'Quantity...
# 2  [{'OrderID': 10250, 'ProductID': 41, 'Quantity...
# 3  [{'OrderID': 10251, 'ProductID': 22, 'Quantity...
# 4  [{'OrderID': 10252, 'ProductID': 20, 'Quantity...

# %% [markdown]
# Nu kan vi göra om hela `orders` till JSON, återigen med *records*-orienteringen.

# %%
order_data = json.loads(orders.to_json(orient="records"))

# %%
order_data
# Out:
# [{'OrderID': 10248,
#   'OrderDate': '1996-07-04 00:00:00',
#   'RequiredDate': '1996-08-01 00:00:00',
#   'ShippedDate': '1996-07-16 00:00:00',
#   'ShipName': 'Vins et alcools Chevalier',
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': "59 rue de l'Abbaye",
#   'ShipPostalCode': '51100',
#   'ShipCity': 'Reims',
#   'OrderDetails': [{'OrderID': 10248,
#     'ProductID': 11,
#     'Quantity': 12,
#     'UnitPrice': 14.0,
#     'Discount': 0.0},
#    {'OrderID': 10248,
#     'ProductID': 42,
#     'Quantity': 10,
#     'UnitPrice': 9.8,
#     'Discount': 0.0},
#    {'OrderID': 10248,
#     'ProductID': 72,
#     'Quantity': 5,
#     'UnitPrice': 34.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10249,
#   'OrderDate': '1996-07-05 00:00:00',
#   'RequiredDate': '1996-08-16 00:00:00',
#   'ShippedDate': '1996-07-10 00:00:00',
#   'ShipName': 'Toms Spezialitäten',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Luisenstr. 48',
#   'ShipPostalCode': '44087',
#   'ShipCity': 'Münster',
#   'OrderDetails': [{'OrderID': 10249,
#     'ProductID': 14,
#     'Quantity': 9,
#     'UnitPrice': 18.6,
#     'Discount': 0.0},
#    {'OrderID': 10249,
#     'ProductID': 51,
#     'Quantity': 40,
#     'UnitPrice': 42.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10250,
#   'OrderDate': '1996-07-08 00:00:00',
#   'RequiredDate': '1996-08-05 00:00:00',
#   'ShippedDate': '1996-07-12 00:00:00',
#   'ShipName': 'Hanari Carnes',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'RJ',
#   'ShipAddress': 'Rua do Paço, 67',
#   'ShipPostalCode': '05454-876',
#   'ShipCity': 'Rio de Janeiro',
#   'OrderDetails': [{'OrderID': 10250,
#     'ProductID': 41,
#     'Quantity': 10,
#     'UnitPrice': 7.7,
#     'Discount': 0.0},
#    {'OrderID': 10250,
#     'ProductID': 51,
#     'Quantity': 35,
#     'UnitPrice': 42.4,
#     'Discount': 0.150000006},
#    {'OrderID': 10250,
#     'ProductID': 65,
#     'Quantity': 15,
#     'UnitPrice': 16.8,
#     'Discount': 0.150000006}]},
#  {'OrderID': 10251,
#   'OrderDate': '1996-07-08 00:00:00',
#   'RequiredDate': '1996-08-05 00:00:00',
#   'ShippedDate': '1996-07-15 00:00:00',
#   'ShipName': 'Victuailles en stock',
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': '2, rue du Commerce',
#   'ShipPostalCode': '69004',
#   'ShipCity': 'Lyon',
#   'OrderDetails': [{'OrderID': 10251,
#     'ProductID': 22,
#     'Quantity': 6,
#     'UnitPrice': 16.8,
#     'Discount': 0.0500000007},
#    {'OrderID': 10251,
#     'ProductID': 57,
#     'Quantity': 15,
#     'UnitPrice': 15.6,
#     'Discount': 0.0500000007},
#    {'OrderID': 10251,
#     'ProductID': 65,
#     'Quantity': 20,
#     'UnitPrice': 16.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10252,
#   'OrderDate': '1996-07-09 00:00:00',
#   'RequiredDate': '1996-08-06 00:00:00',
#   'ShippedDate': '1996-07-11 00:00:00',
#   'ShipName': 'Suprêmes délices',
#   'ShipCountry': 'Belgium',
#   'ShipRegion': None,
#   'ShipAddress': 'Boulevard Tirou, 255',
#   'ShipPostalCode': 'B-6000',
#   'ShipCity': 'Charleroi',
#   'OrderDetails': [{'OrderID': 10252,
#     'ProductID': 20,
#     'Quantity': 40,
#     'UnitPrice': 64.8,
#     'Discount': 0.0500000007},
#    {'OrderID': 10252,
#     'ProductID': 33,
#     'Quantity': 25,
#     'UnitPrice': 2.0,
#     'Discount': 0.0500000007},
#    {'OrderID': 10252,
#     'ProductID': 60,
#     'Quantity': 40,
#     'UnitPrice': 27.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10253,
#   'OrderDate': '1996-07-10 00:00:00',
#   'RequiredDate': '1996-07-24 00:00:00',
#   'ShippedDate': '1996-07-16 00:00:00',
#   'ShipName': 'Hanari Carnes',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'RJ',
#   'ShipAddress': 'Rua do Paço, 67',
#   'ShipPostalCode': '05454-876',
#   'ShipCity': 'Rio de Janeiro',
#   'OrderDetails': [{'OrderID': 10253,
#     'ProductID': 31,
#     'Quantity': 20,
#     'UnitPrice': 10.0,
#     'Discount': 0.0},
#    {'OrderID': 10253,
#     'ProductID': 39,
#     'Quantity': 42,
#     'UnitPrice': 14.4,
#     'Discount': 0.0},
#    {'OrderID': 10253,
#     'ProductID': 49,
#     'Quantity': 40,
#     'UnitPrice': 16.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10254,
#   'OrderDate': '1996-07-11 00:00:00',
#   'RequiredDate': '1996-08-08 00:00:00',
#   'ShippedDate': '1996-07-23 00:00:00',
#   'ShipName': 'Chop-suey Chinese',
#   'ShipCountry': 'Switzerland',
#   'ShipRegion': None,
#   'ShipAddress': 'Hauptstr. 31',
#   'ShipPostalCode': '3012',
#   'ShipCity': 'Bern',
#   'OrderDetails': [{'OrderID': 10254,
#     'ProductID': 24,
#     'Quantity': 15,
#     'UnitPrice': 3.6,
#     'Discount': 0.150000006},
#    {'OrderID': 10254,
#     'ProductID': 55,
#     'Quantity': 21,
#     'UnitPrice': 19.2,
#     'Discount': 0.150000006},
#    {'OrderID': 10254,
#     'ProductID': 74,
#     'Quantity': 21,
#     'UnitPrice': 8.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10255,
#   'OrderDate': '1996-07-12 00:00:00',
#   'RequiredDate': '1996-08-09 00:00:00',
#   'ShippedDate': '1996-07-15 00:00:00',
#   'ShipName': 'Richter Supermarkt',
#   'ShipCountry': 'Switzerland',
#   'ShipRegion': None,
#   'ShipAddress': 'Starenweg 5',
#   'ShipPostalCode': '1204',
#   'ShipCity': 'Genève',
#   'OrderDetails': [{'OrderID': 10255,
#     'ProductID': 2,
#     'Quantity': 20,
#     'UnitPrice': 15.2,
#     'Discount': 0.0},
#    {'OrderID': 10255,
#     'ProductID': 16,
#     'Quantity': 35,
#     'UnitPrice': 13.9,
#     'Discount': 0.0},
#    {'OrderID': 10255,
#     'ProductID': 36,
#     'Quantity': 25,
#     'UnitPrice': 15.2,
#     'Discount': 0.0},
#    {'OrderID': 10255,
#     'ProductID': 59,
#     'Quantity': 30,
#     'UnitPrice': 44.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10256,
#   'OrderDate': '1996-07-15 00:00:00',
#   'RequiredDate': '1996-08-12 00:00:00',
#   'ShippedDate': '1996-07-17 00:00:00',
#   'ShipName': 'Wellington Importadora',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'SP',
#   'ShipAddress': 'Rua do Mercado, 12',
#   'ShipPostalCode': '08737-363',
#   'ShipCity': 'Resende',
#   'OrderDetails': [{'OrderID': 10256,
#     'ProductID': 53,
#     'Quantity': 15,
#     'UnitPrice': 26.2,
#     'Discount': 0.0},
#    {'OrderID': 10256,
#     'ProductID': 77,
#     'Quantity': 12,
#     'UnitPrice': 10.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10257,
#   'OrderDate': '1996-07-16 00:00:00',
#   'RequiredDate': '1996-08-13 00:00:00',
#   'ShippedDate': '1996-07-22 00:00:00',
#   'ShipName': 'HILARION-Abastos',
#   'ShipCountry': 'Venezuela',
#   'ShipRegion': 'Táchira',
#   'ShipAddress': 'Carrera 22 con Ave. Carlos Soublette #8-35',
#   'ShipPostalCode': '5022',
#   'ShipCity': 'San Cristóbal',
#   'OrderDetails': [{'OrderID': 10257,
#     'ProductID': 27,
#     'Quantity': 25,
#     'UnitPrice': 35.1,
#     'Discount': 0.0},
#    {'OrderID': 10257,
#     'ProductID': 39,
#     'Quantity': 6,
#     'UnitPrice': 14.4,
#     'Discount': 0.0},
#    {'OrderID': 10257,
#     'ProductID': 77,
#     'Quantity': 15,
#     'UnitPrice': 10.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10258,
#   'OrderDate': '1996-07-17 00:00:00',
#   'RequiredDate': '1996-08-14 00:00:00',
#   'ShippedDate': '1996-07-23 00:00:00',
#   'ShipName': 'Ernst Handel',
#   'ShipCountry': 'Austria',
#   'ShipRegion': None,
#   'ShipAddress': 'Kirchgasse 6',
#   'ShipPostalCode': '8010',
#   'ShipCity': 'Graz',
#   'OrderDetails': [{'OrderID': 10258,
#     'ProductID': 2,
#     'Quantity': 50,
#     'UnitPrice': 15.2,
#     'Discount': 0.200000003},
#    {'OrderID': 10258,
#     'ProductID': 5,
#     'Quantity': 65,
#     'UnitPrice': 17.0,
#     'Discount': 0.200000003},
#    {'OrderID': 10258,
#     'ProductID': 32,
#     'Quantity': 6,
#     'UnitPrice': 25.6,
#     'Discount': 0.200000003}]},
#  {'OrderID': 10259,
#   'OrderDate': '1996-07-18 00:00:00',
#   'RequiredDate': '1996-08-15 00:00:00',
#   'ShippedDate': '1996-07-25 00:00:00',
#   'ShipName': 'Centro comercial Moctezuma',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Sierras de Granada 9993',
#   'ShipPostalCode': '05022',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 10259,
#     'ProductID': 21,
#     'Quantity': 10,
#     'UnitPrice': 8.0,
#     'Discount': 0.0},
#    {'OrderID': 10259,
#     'ProductID': 37,
#     'Quantity': 1,
#     'UnitPrice': 20.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10260,
#   'OrderDate': '1996-07-19 00:00:00',
#   'RequiredDate': '1996-08-16 00:00:00',
#   'ShippedDate': '1996-07-29 00:00:00',
#   'ShipName': 'Ottilies Käseladen',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Mehrheimerstr. 369',
#   'ShipPostalCode': '50739',
#   'ShipCity': 'Köln',
#   'OrderDetails': [{'OrderID': 10260,
#     'ProductID': 41,
#     'Quantity': 16,
#     'UnitPrice': 7.7,
#     'Discount': 0.25},
#    {'OrderID': 10260,
#     'ProductID': 57,
#     'Quantity': 50,
#     'UnitPrice': 15.6,
#     'Discount': 0.0},
#    {'OrderID': 10260,
#     'ProductID': 62,
#     'Quantity': 15,
#     'UnitPrice': 39.4,
#     'Discount': 0.25},
#    {'OrderID': 10260,
#     'ProductID': 70,
#     'Quantity': 21,
#     'UnitPrice': 12.0,
#     'Discount': 0.25}]},
#  {'OrderID': 10261,
#   'OrderDate': '1996-07-19 00:00:00',
#   'RequiredDate': '1996-08-16 00:00:00',
#   'ShippedDate': '1996-07-30 00:00:00',
#   'ShipName': 'Que Delícia',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'RJ',
#   'ShipAddress': 'Rua da Panificadora, 12',
#   'ShipPostalCode': '02389-673',
#   'ShipCity': 'Rio de Janeiro',
#   'OrderDetails': [{'OrderID': 10261,
#     'ProductID': 21,
#     'Quantity': 20,
#     'UnitPrice': 8.0,
#     'Discount': 0.0},
#    {'OrderID': 10261,
#     'ProductID': 35,
#     'Quantity': 20,
#     'UnitPrice': 14.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10262,
#   'OrderDate': '1996-07-22 00:00:00',
#   'RequiredDate': '1996-08-19 00:00:00',
#   'ShippedDate': '1996-07-25 00:00:00',
#   'ShipName': 'Rattlesnake Canyon Grocery',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'NM',
#   'ShipAddress': '2817 Milton Dr.',
#   'ShipPostalCode': '87110',
#   'ShipCity': 'Albuquerque',
#   'OrderDetails': [{'OrderID': 10262,
#     'ProductID': 5,
#     'Quantity': 12,
#     'UnitPrice': 17.0,
#     'Discount': 0.200000003},
#    {'OrderID': 10262,
#     'ProductID': 7,
#     'Quantity': 15,
#     'UnitPrice': 24.0,
#     'Discount': 0.0},
#    {'OrderID': 10262,
#     'ProductID': 56,
#     'Quantity': 2,
#     'UnitPrice': 30.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10263,
#   'OrderDate': '1996-07-23 00:00:00',
#   'RequiredDate': '1996-08-20 00:00:00',
#   'ShippedDate': '1996-07-31 00:00:00',
#   'ShipName': 'Ernst Handel',
#   'ShipCountry': 'Austria',
#   'ShipRegion': None,
#   'ShipAddress': 'Kirchgasse 6',
#   'ShipPostalCode': '8010',
#   'ShipCity': 'Graz',
#   'OrderDetails': [{'OrderID': 10263,
#     'ProductID': 16,
#     'Quantity': 60,
#     'UnitPrice': 13.9,
#     'Discount': 0.25},
#    {'OrderID': 10263,
#     'ProductID': 24,
#     'Quantity': 28,
#     'UnitPrice': 3.6,
#     'Discount': 0.0},
#    {'OrderID': 10263,
#     'ProductID': 30,
#     'Quantity': 60,
#     'UnitPrice': 20.7,
#     'Discount': 0.25},
#    {'OrderID': 10263,
#     'ProductID': 74,
#     'Quantity': 36,
#     'UnitPrice': 8.0,
#     'Discount': 0.25}]},
#  {'OrderID': 10264,
#   'OrderDate': '1996-07-24 00:00:00',
#   'RequiredDate': '1996-08-21 00:00:00',
#   'ShippedDate': '1996-08-23 00:00:00',
#   'ShipName': 'Folk och fä HB',
#   'ShipCountry': 'Sweden',
#   'ShipRegion': None,
#   'ShipAddress': 'Åkergatan 24',
#   'ShipPostalCode': 'S-844 67',
#   'ShipCity': 'Bräcke',
#   'OrderDetails': [{'OrderID': 10264,
#     'ProductID': 2,
#     'Quantity': 35,
#     'UnitPrice': 15.2,
#     'Discount': 0.0},
#    {'OrderID': 10264,
#     'ProductID': 41,
#     'Quantity': 25,
#     'UnitPrice': 7.7,
#     'Discount': 0.150000006}]},
#  {'OrderID': 10265,
#   'OrderDate': '1996-07-25 00:00:00',
#   'RequiredDate': '1996-08-22 00:00:00',
#   'ShippedDate': '1996-08-12 00:00:00',
#   'ShipName': 'Blondel père et fils',
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': '24, place Kléber',
#   'ShipPostalCode': '67000',
#   'ShipCity': 'Strasbourg',
#   'OrderDetails': [{'OrderID': 10265,
#     'ProductID': 17,
#     'Quantity': 30,
#     'UnitPrice': 31.2,
#     'Discount': 0.0},
#    {'OrderID': 10265,
#     'ProductID': 70,
#     'Quantity': 20,
#     'UnitPrice': 12.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10266,
#   'OrderDate': '1996-07-26 00:00:00',
#   'RequiredDate': '1996-09-06 00:00:00',
#   'ShippedDate': '1996-07-31 00:00:00',
#   'ShipName': 'Wartian Herkku',
#   'ShipCountry': 'Finland',
#   'ShipRegion': None,
#   'ShipAddress': 'Torikatu 38',
#   'ShipPostalCode': '90110',
#   'ShipCity': 'Oulu',
#   'OrderDetails': [{'OrderID': 10266,
#     'ProductID': 12,
#     'Quantity': 12,
#     'UnitPrice': 30.4,
#     'Discount': 0.0500000007}]},
#  {'OrderID': 10267,
#   'OrderDate': '1996-07-29 00:00:00',
#   'RequiredDate': '1996-08-26 00:00:00',
#   'ShippedDate': '1996-08-06 00:00:00',
#   'ShipName': 'Frankenversand',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Berliner Platz 43',
#   'ShipPostalCode': '80805',
#   'ShipCity': 'München',
#   'OrderDetails': [{'OrderID': 10267,
#     'ProductID': 40,
#     'Quantity': 50,
#     'UnitPrice': 14.7,
#     'Discount': 0.0},
#    {'OrderID': 10267,
#     'ProductID': 59,
#     'Quantity': 70,
#     'UnitPrice': 44.0,
#     'Discount': 0.150000006},
#    {'OrderID': 10267,
#     'ProductID': 76,
#     'Quantity': 15,
#     'UnitPrice': 14.4,
#     'Discount': 0.150000006}]},
#  {'OrderID': 10268,
#   'OrderDate': '1996-07-30 00:00:00',
#   'RequiredDate': '1996-08-27 00:00:00',
#   'ShippedDate': '1996-08-02 00:00:00',
#   'ShipName': 'GROSELLA-Restaurante',
#   'ShipCountry': 'Venezuela',
#   'ShipRegion': 'DF',
#   'ShipAddress': '5ª Ave. Los Palos Grandes',
#   'ShipPostalCode': '1081',
#   'ShipCity': 'Caracas',
#   'OrderDetails': [{'OrderID': 10268,
#     'ProductID': 29,
#     'Quantity': 10,
#     'UnitPrice': 99.0,
#     'Discount': 0.0},
#    {'OrderID': 10268,
#     'ProductID': 72,
#     'Quantity': 4,
#     'UnitPrice': 27.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10269,
#   'OrderDate': '1996-07-31 00:00:00',
#   'RequiredDate': '1996-08-14 00:00:00',
#   'ShippedDate': '1996-08-09 00:00:00',
#   'ShipName': 'White Clover Markets',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'WA',
#   'ShipAddress': '1029 - 12th Ave. S.',
#   'ShipPostalCode': '98124',
#   'ShipCity': 'Seattle',
#   'OrderDetails': [{'OrderID': 10269,
#     'ProductID': 33,
#     'Quantity': 60,
#     'UnitPrice': 2.0,
#     'Discount': 0.0500000007},
#    {'OrderID': 10269,
#     'ProductID': 72,
#     'Quantity': 20,
#     'UnitPrice': 27.8,
#     'Discount': 0.0500000007}]},
#  {'OrderID': 10270,
#   'OrderDate': '1996-08-01 00:00:00',
#   'RequiredDate': '1996-08-29 00:00:00',
#   'ShippedDate': '1996-08-02 00:00:00',
#   'ShipName': 'Wartian Herkku',
#   'ShipCountry': 'Finland',
#   'ShipRegion': None,
#   'ShipAddress': 'Torikatu 38',
#   'ShipPostalCode': '90110',
#   'ShipCity': 'Oulu',
#   'OrderDetails': [{'OrderID': 10270,
#     'ProductID': 36,
#     'Quantity': 30,
#     'UnitPrice': 15.2,
#     'Discount': 0.0},
#    {'OrderID': 10270,
#     'ProductID': 43,
#     'Quantity': 25,
#     'UnitPrice': 36.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10271,
#   'OrderDate': '1996-08-01 00:00:00',
#   'RequiredDate': '1996-08-29 00:00:00',
#   'ShippedDate': '1996-08-30 00:00:00',
#   'ShipName': 'Split Rail Beer & Ale',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'WY',
#   'ShipAddress': 'P.O. Box 555',
#   'ShipPostalCode': '82520',
#   'ShipCity': 'Lander',
#   'OrderDetails': [{'OrderID': 10271,
#     'ProductID': 33,
#     'Quantity': 24,
#     'UnitPrice': 2.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10272,
#   'OrderDate': '1996-08-02 00:00:00',
#   'RequiredDate': '1996-08-30 00:00:00',
#   'ShippedDate': '1996-08-06 00:00:00',
#   'ShipName': 'Rattlesnake Canyon Grocery',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'NM',
#   'ShipAddress': '2817 Milton Dr.',
#   'ShipPostalCode': '87110',
#   'ShipCity': 'Albuquerque',
#   'OrderDetails': [{'OrderID': 10272,
#     'ProductID': 20,
#     'Quantity': 6,
#     'UnitPrice': 64.8,
#     'Discount': 0.0},
#    {'OrderID': 10272,
#     'ProductID': 31,
#     'Quantity': 40,
#     'UnitPrice': 10.0,
#     'Discount': 0.0},
#    {'OrderID': 10272,
#     'ProductID': 72,
#     'Quantity': 24,
#     'UnitPrice': 27.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10273,
#   'OrderDate': '1996-08-05 00:00:00',
#   'RequiredDate': '1996-09-02 00:00:00',
#   'ShippedDate': '1996-08-12 00:00:00',
#   'ShipName': 'QUICK-Stop',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Taucherstraße 10',
#   'ShipPostalCode': '01307',
#   'ShipCity': 'Cunewalde',
#   'OrderDetails': [{'OrderID': 10273,
#     'ProductID': 10,
#     'Quantity': 24,
#     'UnitPrice': 24.8,
#     'Discount': 0.0500000007},
#    {'OrderID': 10273,
#     'ProductID': 31,
#     'Quantity': 15,
#     'UnitPrice': 10.0,
#     'Discount': 0.0500000007},
#    {'OrderID': 10273,
#     'ProductID': 33,
#     'Quantity': 20,
#     'UnitPrice': 2.0,
#     'Discount': 0.0},
#    {'OrderID': 10273,
#     'ProductID': 40,
#     'Quantity': 60,
#     'UnitPrice': 14.7,
#     'Discount': 0.0500000007},
#    {'OrderID': 10273,
#     'ProductID': 76,
#     'Quantity': 33,
#     'UnitPrice': 14.4,
#     'Discount': 0.0500000007}]},
#  {'OrderID': 10274,
#   'OrderDate': '1996-08-06 00:00:00',
#   'RequiredDate': '1996-09-03 00:00:00',
#   'ShippedDate': '1996-08-16 00:00:00',
#   'ShipName': 'Vins et alcools Chevalier',
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': "59 rue de l'Abbaye",
#   'ShipPostalCode': '51100',
#   'ShipCity': 'Reims',
#   'OrderDetails': [{'OrderID': 10274,
#     'ProductID': 71,
#     'Quantity': 20,
#     'UnitPrice': 17.2,
#     'Discount': 0.0},
#    {'OrderID': 10274,
#     'ProductID': 72,
#     'Quantity': 7,
#     'UnitPrice': 27.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10275,
#   'OrderDate': '1996-08-07 00:00:00',
#   'RequiredDate': '1996-09-04 00:00:00',
#   'ShippedDate': '1996-08-09 00:00:00',
#   'ShipName': 'Magazzini Alimentari Riuniti',
#   'ShipCountry': 'Italy',
#   'ShipRegion': None,
#   'ShipAddress': 'Via Ludovico il Moro 22',
#   'ShipPostalCode': '24100',
#   'ShipCity': 'Bergamo',
#   'OrderDetails': [{'OrderID': 10275,
#     'ProductID': 24,
#     'Quantity': 12,
#     'UnitPrice': 3.6,
#     'Discount': 0.0500000007},
#    {'OrderID': 10275,
#     'ProductID': 59,
#     'Quantity': 6,
#     'UnitPrice': 44.0,
#     'Discount': 0.0500000007}]},
#  {'OrderID': 10276,
#   'OrderDate': '1996-08-08 00:00:00',
#   'RequiredDate': '1996-08-22 00:00:00',
#   'ShippedDate': '1996-08-14 00:00:00',
#   'ShipName': 'Tortuga Restaurante',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Avda. Azteca 123',
#   'ShipPostalCode': '05033',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 10276,
#     'ProductID': 10,
#     'Quantity': 15,
#     'UnitPrice': 24.8,
#     'Discount': 0.0},
#    {'OrderID': 10276,
#     'ProductID': 13,
#     'Quantity': 10,
#     'UnitPrice': 4.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10277,
#   'OrderDate': '1996-08-09 00:00:00',
#   'RequiredDate': '1996-09-06 00:00:00',
#   'ShippedDate': '1996-08-13 00:00:00',
#   'ShipName': 'Morgenstern Gesundkost',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Heerstr. 22',
#   'ShipPostalCode': '04179',
#   'ShipCity': 'Leipzig',
#   'OrderDetails': [{'OrderID': 10277,
#     'ProductID': 28,
#     'Quantity': 20,
#     'UnitPrice': 36.4,
#     'Discount': 0.0},
#    {'OrderID': 10277,
#     'ProductID': 62,
#     'Quantity': 12,
#     'UnitPrice': 39.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10278,
#   'OrderDate': '1996-08-12 00:00:00',
#   'RequiredDate': '1996-09-09 00:00:00',
#   'ShippedDate': '1996-08-16 00:00:00',
#   'ShipName': 'Berglunds snabbköp',
#   'ShipCountry': 'Sweden',
#   'ShipRegion': None,
#   'ShipAddress': 'Berguvsvägen  8',
#   'ShipPostalCode': 'S-958 22',
#   'ShipCity': 'Luleå',
#   'OrderDetails': [{'OrderID': 10278,
#     'ProductID': 44,
#     'Quantity': 16,
#     'UnitPrice': 15.5,
#     'Discount': 0.0},
#    {'OrderID': 10278,
#     'ProductID': 59,
#     'Quantity': 15,
#     'UnitPrice': 44.0,
#     'Discount': 0.0},
#    {'OrderID': 10278,
#     'ProductID': 63,
#     'Quantity': 8,
#     'UnitPrice': 35.1,
#     'Discount': 0.0},
#    {'OrderID': 10278,
#     'ProductID': 73,
#     'Quantity': 25,
#     'UnitPrice': 12.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10279,
#   'OrderDate': '1996-08-13 00:00:00',
#   'RequiredDate': '1996-09-10 00:00:00',
#   'ShippedDate': '1996-08-16 00:00:00',
#   'ShipName': 'Lehmanns Marktstand',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Magazinweg 7',
#   'ShipPostalCode': '60528',
#   'ShipCity': 'Frankfurt a.M.',
#   'OrderDetails': [{'OrderID': 10279,
#     'ProductID': 17,
#     'Quantity': 15,
#     'UnitPrice': 31.2,
#     'Discount': 0.25}]},
#  {'OrderID': 10280,
#   'OrderDate': '1996-08-14 00:00:00',
#   'RequiredDate': '1996-09-11 00:00:00',
#   'ShippedDate': '1996-09-12 00:00:00',
#   'ShipName': 'Berglunds snabbköp',
#   'ShipCountry': 'Sweden',
#   'ShipRegion': None,
#   'ShipAddress': 'Berguvsvägen  8',
#   'ShipPostalCode': 'S-958 22',
#   'ShipCity': 'Luleå',
#   'OrderDetails': [{'OrderID': 10280,
#     'ProductID': 24,
#     'Quantity': 12,
#     'UnitPrice': 3.6,
#     'Discount': 0.0},
#    {'OrderID': 10280,
#     'ProductID': 55,
#     'Quantity': 20,
#     'UnitPrice': 19.2,
#     'Discount': 0.0},
#    {'OrderID': 10280,
#     'ProductID': 75,
#     'Quantity': 30,
#     'UnitPrice': 6.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10281,
#   'OrderDate': '1996-08-14 00:00:00',
#   'RequiredDate': '1996-08-28 00:00:00',
#   'ShippedDate': '1996-08-21 00:00:00',
#   'ShipName': 'Romero y tomillo',
#   'ShipCountry': 'Spain',
#   'ShipRegion': None,
#   'ShipAddress': 'Gran Vía, 1',
#   'ShipPostalCode': '28001',
#   'ShipCity': 'Madrid',
#   'OrderDetails': [{'OrderID': 10281,
#     'ProductID': 19,
#     'Quantity': 1,
#     'UnitPrice': 7.3,
#     'Discount': 0.0},
#    {'OrderID': 10281,
#     'ProductID': 24,
#     'Quantity': 6,
#     'UnitPrice': 3.6,
#     'Discount': 0.0},
#    {'OrderID': 10281,
#     'ProductID': 35,
#     'Quantity': 4,
#     'UnitPrice': 14.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10282,
#   'OrderDate': '1996-08-15 00:00:00',
#   'RequiredDate': '1996-09-12 00:00:00',
#   'ShippedDate': '1996-08-21 00:00:00',
#   'ShipName': 'Romero y tomillo',
#   'ShipCountry': 'Spain',
#   'ShipRegion': None,
#   'ShipAddress': 'Gran Vía, 1',
#   'ShipPostalCode': '28001',
#   'ShipCity': 'Madrid',
#   'OrderDetails': [{'OrderID': 10282,
#     'ProductID': 30,
#     'Quantity': 6,
#     'UnitPrice': 20.7,
#     'Discount': 0.0},
#    {'OrderID': 10282,
#     'ProductID': 57,
#     'Quantity': 2,
#     'UnitPrice': 15.6,
#     'Discount': 0.0}]},
#  {'OrderID': 10283,
#   'OrderDate': '1996-08-16 00:00:00',
#   'RequiredDate': '1996-09-13 00:00:00',
#   'ShippedDate': '1996-08-23 00:00:00',
#   'ShipName': 'LILA-Supermercado',
#   'ShipCountry': 'Venezuela',
#   'ShipRegion': 'Lara',
#   'ShipAddress': 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo',
#   'ShipPostalCode': '3508',
#   'ShipCity': 'Barquisimeto',
#   'OrderDetails': [{'OrderID': 10283,
#     'ProductID': 15,
#     'Quantity': 20,
#     'UnitPrice': 12.4,
#     'Discount': 0.0},
#    {'OrderID': 10283,
#     'ProductID': 19,
#     'Quantity': 18,
#     'UnitPrice': 7.3,
#     'Discount': 0.0},
#    {'OrderID': 10283,
#     'ProductID': 60,
#     'Quantity': 35,
#     'UnitPrice': 27.2,
#     'Discount': 0.0},
#    {'OrderID': 10283,
#     'ProductID': 72,
#     'Quantity': 3,
#     'UnitPrice': 27.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10284,
#   'OrderDate': '1996-08-19 00:00:00',
#   'RequiredDate': '1996-09-16 00:00:00',
#   'ShippedDate': '1996-08-27 00:00:00',
#   'ShipName': 'Lehmanns Marktstand',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Magazinweg 7',
#   'ShipPostalCode': '60528',
#   'ShipCity': 'Frankfurt a.M.',
#   'OrderDetails': [{'OrderID': 10284,
#     'ProductID': 27,
#     'Quantity': 15,
#     'UnitPrice': 35.1,
#     'Discount': 0.25},
#    {'OrderID': 10284,
#     'ProductID': 44,
#     'Quantity': 21,
#     'UnitPrice': 15.5,
#     'Discount': 0.0},
#    {'OrderID': 10284,
#     'ProductID': 60,
#     'Quantity': 20,
#     'UnitPrice': 27.2,
#     'Discount': 0.25},
#    {'OrderID': 10284,
#     'ProductID': 67,
#     'Quantity': 5,
#     'UnitPrice': 11.2,
#     'Discount': 0.25}]},
#  {'OrderID': 10285,
#   'OrderDate': '1996-08-20 00:00:00',
#   'RequiredDate': '1996-09-17 00:00:00',
#   'ShippedDate': '1996-08-26 00:00:00',
#   'ShipName': 'QUICK-Stop',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Taucherstraße 10',
#   'ShipPostalCode': '01307',
#   'ShipCity': 'Cunewalde',
#   'OrderDetails': [{'OrderID': 10285,
#     'ProductID': 1,
#     'Quantity': 45,
#     'UnitPrice': 14.4,
#     'Discount': 0.200000003},
#    {'OrderID': 10285,
#     'ProductID': 40,
#     'Quantity': 40,
#     'UnitPrice': 14.7,
#     'Discount': 0.200000003},
#    {'OrderID': 10285,
#     'ProductID': 53,
#     'Quantity': 36,
#     'UnitPrice': 26.2,
#     'Discount': 0.200000003}]},
#  {'OrderID': 10286,
#   'OrderDate': '1996-08-21 00:00:00',
#   'RequiredDate': '1996-09-18 00:00:00',
#   'ShippedDate': '1996-08-30 00:00:00',
#   'ShipName': 'QUICK-Stop',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Taucherstraße 10',
#   'ShipPostalCode': '01307',
#   'ShipCity': 'Cunewalde',
#   'OrderDetails': [{'OrderID': 10286,
#     'ProductID': 35,
#     'Quantity': 100,
#     'UnitPrice': 14.4,
#     'Discount': 0.0},
#    {'OrderID': 10286,
#     'ProductID': 62,
#     'Quantity': 40,
#     'UnitPrice': 39.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10287,
#   'OrderDate': '1996-08-22 00:00:00',
#   'RequiredDate': '1996-09-19 00:00:00',
#   'ShippedDate': '1996-08-28 00:00:00',
#   'ShipName': 'Ricardo Adocicados',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'RJ',
#   'ShipAddress': 'Av. Copacabana, 267',
#   'ShipPostalCode': '02389-890',
#   'ShipCity': 'Rio de Janeiro',
#   'OrderDetails': [{'OrderID': 10287,
#     'ProductID': 16,
#     'Quantity': 40,
#     'UnitPrice': 13.9,
#     'Discount': 0.150000006},
#    {'OrderID': 10287,
#     'ProductID': 34,
#     'Quantity': 20,
#     'UnitPrice': 11.2,
#     'Discount': 0.0},
#    {'OrderID': 10287,
#     'ProductID': 46,
#     'Quantity': 15,
#     'UnitPrice': 9.6,
#     'Discount': 0.150000006}]},
#  {'OrderID': 10288,
#   'OrderDate': '1996-08-23 00:00:00',
#   'RequiredDate': '1996-09-20 00:00:00',
#   'ShippedDate': '1996-09-03 00:00:00',
#   'ShipName': 'Reggiani Caseifici',
#   'ShipCountry': 'Italy',
#   'ShipRegion': None,
#   'ShipAddress': 'Strada Provinciale 124',
#   'ShipPostalCode': '42100',
#   'ShipCity': 'Reggio Emilia',
#   'OrderDetails': [{'OrderID': 10288,
#     'ProductID': 54,
#     'Quantity': 10,
#     'UnitPrice': 5.9,
#     'Discount': 0.1000000015},
#    {'OrderID': 10288,
#     'ProductID': 68,
#     'Quantity': 3,
#     'UnitPrice': 10.0,
#     'Discount': 0.1000000015}]},
#  {'OrderID': 10289,
#   'OrderDate': '1996-08-26 00:00:00',
#   'RequiredDate': '1996-09-23 00:00:00',
#   'ShippedDate': '1996-08-28 00:00:00',
#   'ShipName': "B's Beverages",
#   'ShipCountry': 'UK',
#   'ShipRegion': None,
#   'ShipAddress': 'Fauntleroy Circus',
#   'ShipPostalCode': 'EC2 5NT',
#   'ShipCity': 'London',
#   'OrderDetails': [{'OrderID': 10289,
#     'ProductID': 3,
#     'Quantity': 30,
#     'UnitPrice': 8.0,
#     'Discount': 0.0},
#    {'OrderID': 10289,
#     'ProductID': 64,
#     'Quantity': 9,
#     'UnitPrice': 26.6,
#     'Discount': 0.0}]},
#  {'OrderID': 10290,
#   'OrderDate': '1996-08-27 00:00:00',
#   'RequiredDate': '1996-09-24 00:00:00',
#   'ShippedDate': '1996-09-03 00:00:00',
#   'ShipName': 'Comércio Mineiro',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'SP',
#   'ShipAddress': 'Av. dos Lusíadas, 23',
#   'ShipPostalCode': '05432-043',
#   'ShipCity': 'Sao Paulo',
#   'OrderDetails': [{'OrderID': 10290,
#     'ProductID': 5,
#     'Quantity': 20,
#     'UnitPrice': 17.0,
#     'Discount': 0.0},
#    {'OrderID': 10290,
#     'ProductID': 29,
#     'Quantity': 15,
#     'UnitPrice': 99.0,
#     'Discount': 0.0},
#    {'OrderID': 10290,
#     'ProductID': 49,
#     'Quantity': 15,
#     'UnitPrice': 16.0,
#     'Discount': 0.0},
#    {'OrderID': 10290,
#     'ProductID': 77,
#     'Quantity': 10,
#     'UnitPrice': 10.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10291,
#   'OrderDate': '1996-08-27 00:00:00',
#   'RequiredDate': '1996-09-24 00:00:00',
#   'ShippedDate': '1996-09-04 00:00:00',
#   'ShipName': 'Que Delícia',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'RJ',
#   'ShipAddress': 'Rua da Panificadora, 12',
#   'ShipPostalCode': '02389-673',
#   'ShipCity': 'Rio de Janeiro',
#   'OrderDetails': [{'OrderID': 10291,
#     'ProductID': 13,
#     'Quantity': 20,
#     'UnitPrice': 4.8,
#     'Discount': 0.1000000015},
#    {'OrderID': 10291,
#     'ProductID': 44,
#     'Quantity': 24,
#     'UnitPrice': 15.5,
#     'Discount': 0.1000000015},
#    {'OrderID': 10291,
#     'ProductID': 51,
#     'Quantity': 2,
#     'UnitPrice': 42.4,
#     'Discount': 0.1000000015}]},
#  {'OrderID': 10292,
#   'OrderDate': '1996-08-28 00:00:00',
#   'RequiredDate': '1996-09-25 00:00:00',
#   'ShippedDate': '1996-09-02 00:00:00',
#   'ShipName': 'Tradiçao Hipermercados',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'SP',
#   'ShipAddress': 'Av. Inês de Castro, 414',
#   'ShipPostalCode': '05634-030',
#   'ShipCity': 'Sao Paulo',
#   'OrderDetails': [{'OrderID': 10292,
#     'ProductID': 20,
#     'Quantity': 20,
#     'UnitPrice': 64.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10293,
#   'OrderDate': '1996-08-29 00:00:00',
#   'RequiredDate': '1996-09-26 00:00:00',
#   'ShippedDate': '1996-09-11 00:00:00',
#   'ShipName': 'Tortuga Restaurante',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Avda. Azteca 123',
#   'ShipPostalCode': '05033',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 10293,
#     'ProductID': 18,
#     'Quantity': 12,
#     'UnitPrice': 50.0,
#     'Discount': 0.0},
#    {'OrderID': 10293,
#     'ProductID': 24,
#     'Quantity': 10,
#     'UnitPrice': 3.6,
#     'Discount': 0.0},
#    {'OrderID': 10293,
#     'ProductID': 63,
#     'Quantity': 5,
#     'UnitPrice': 35.1,
#     'Discount': 0.0},
#    {'OrderID': 10293,
#     'ProductID': 75,
#     'Quantity': 6,
#     'UnitPrice': 6.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10294,
#   'OrderDate': '1996-08-30 00:00:00',
#   'RequiredDate': '1996-09-27 00:00:00',
#   'ShippedDate': '1996-09-05 00:00:00',
#   'ShipName': 'Rattlesnake Canyon Grocery',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'NM',
#   'ShipAddress': '2817 Milton Dr.',
#   'ShipPostalCode': '87110',
#   'ShipCity': 'Albuquerque',
#   'OrderDetails': [{'OrderID': 10294,
#     'ProductID': 1,
#     'Quantity': 18,
#     'UnitPrice': 14.4,
#     'Discount': 0.0},
#    {'OrderID': 10294,
#     'ProductID': 17,
#     'Quantity': 15,
#     'UnitPrice': 31.2,
#     'Discount': 0.0},
#    {'OrderID': 10294,
#     'ProductID': 43,
#     'Quantity': 15,
#     'UnitPrice': 36.8,
#     'Discount': 0.0},
#    {'OrderID': 10294,
#     'ProductID': 60,
#     'Quantity': 21,
#     'UnitPrice': 27.2,
#     'Discount': 0.0},
#    {'OrderID': 10294,
#     'ProductID': 75,
#     'Quantity': 6,
#     'UnitPrice': 6.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10295,
#   'OrderDate': '1996-09-02 00:00:00',
#   'RequiredDate': '1996-09-30 00:00:00',
#   'ShippedDate': '1996-09-10 00:00:00',
#   'ShipName': 'Vins et alcools Chevalier',
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': "59 rue de l'Abbaye",
#   'ShipPostalCode': '51100',
#   'ShipCity': 'Reims',
#   'OrderDetails': [{'OrderID': 10295,
#     'ProductID': 56,
#     'Quantity': 4,
#     'UnitPrice': 30.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10296,
#   'OrderDate': '1996-09-03 00:00:00',
#   'RequiredDate': '1996-10-01 00:00:00',
#   'ShippedDate': '1996-09-11 00:00:00',
#   'ShipName': 'LILA-Supermercado',
#   'ShipCountry': 'Venezuela',
#   'ShipRegion': 'Lara',
#   'ShipAddress': 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo',
#   'ShipPostalCode': '3508',
#   'ShipCity': 'Barquisimeto',
#   'OrderDetails': [{'OrderID': 10296,
#     'ProductID': 11,
#     'Quantity': 12,
#     'UnitPrice': 16.8,
#     'Discount': 0.0},
#    {'OrderID': 10296,
#     'ProductID': 16,
#     'Quantity': 30,
#     'UnitPrice': 13.9,
#     'Discount': 0.0},
#    {'OrderID': 10296,
#     'ProductID': 69,
#     'Quantity': 15,
#     'UnitPrice': 28.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10297,
#   'OrderDate': '1996-09-04 00:00:00',
#   'RequiredDate': '1996-10-16 00:00:00',
#   'ShippedDate': '1996-09-10 00:00:00',
#   'ShipName': 'Blondel père et fils',
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': '24, place Kléber',
#   'ShipPostalCode': '67000',
#   'ShipCity': 'Strasbourg',
#   'OrderDetails': [{'OrderID': 10297,
#     'ProductID': 39,
#     'Quantity': 60,
#     'UnitPrice': 14.4,
#     'Discount': 0.0},
#    {'OrderID': 10297,
#     'ProductID': 72,
#     'Quantity': 20,
#     'UnitPrice': 27.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10298,
#   'OrderDate': '1996-09-05 00:00:00',
#   'RequiredDate': '1996-10-03 00:00:00',
#   'ShippedDate': '1996-09-11 00:00:00',
#   'ShipName': 'Hungry Owl All-Night Grocers',
#   'ShipCountry': 'Ireland',
#   'ShipRegion': 'Co. Cork',
#   'ShipAddress': '8 Johnstown Road',
#   'ShipPostalCode': None,
#   'ShipCity': 'Cork',
#   'OrderDetails': [{'OrderID': 10298,
#     'ProductID': 2,
#     'Quantity': 40,
#     'UnitPrice': 15.2,
#     'Discount': 0.0},
#    {'OrderID': 10298,
#     'ProductID': 36,
#     'Quantity': 40,
#     'UnitPrice': 15.2,
#     'Discount': 0.25},
#    {'OrderID': 10298,
#     'ProductID': 59,
#     'Quantity': 30,
#     'UnitPrice': 44.0,
#     'Discount': 0.25},
#    {'OrderID': 10298,
#     'ProductID': 62,
#     'Quantity': 15,
#     'UnitPrice': 39.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10299,
#   'OrderDate': '1996-09-06 00:00:00',
#   'RequiredDate': '1996-10-04 00:00:00',
#   'ShippedDate': '1996-09-13 00:00:00',
#   'ShipName': 'Ricardo Adocicados',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'RJ',
#   'ShipAddress': 'Av. Copacabana, 267',
#   'ShipPostalCode': '02389-890',
#   'ShipCity': 'Rio de Janeiro',
#   'OrderDetails': [{'OrderID': 10299,
#     'ProductID': 19,
#     'Quantity': 15,
#     'UnitPrice': 7.3,
#     'Discount': 0.0},
#    {'OrderID': 10299,
#     'ProductID': 70,
#     'Quantity': 20,
#     'UnitPrice': 12.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10300,
#   'OrderDate': '1996-09-09 00:00:00',
#   'RequiredDate': '1996-10-07 00:00:00',
#   'ShippedDate': '1996-09-18 00:00:00',
#   'ShipName': 'Magazzini Alimentari Riuniti',
#   'ShipCountry': 'Italy',
#   'ShipRegion': None,
#   'ShipAddress': 'Via Ludovico il Moro 22',
#   'ShipPostalCode': '24100',
#   'ShipCity': 'Bergamo',
#   'OrderDetails': [{'OrderID': 10300,
#     'ProductID': 66,
#     'Quantity': 30,
#     'UnitPrice': 13.6,
#     'Discount': 0.0},
#    {'OrderID': 10300,
#     'ProductID': 68,
#     'Quantity': 20,
#     'UnitPrice': 10.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10301,
#   'OrderDate': '1996-09-09 00:00:00',
#   'RequiredDate': '1996-10-07 00:00:00',
#   'ShippedDate': '1996-09-17 00:00:00',
#   'ShipName': 'Die Wandernde Kuh',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Adenauerallee 900',
#   'ShipPostalCode': '70563',
#   'ShipCity': 'Stuttgart',
#   'OrderDetails': [{'OrderID': 10301,
#     'ProductID': 40,
#     'Quantity': 10,
#     'UnitPrice': 14.7,
#     'Discount': 0.0},
#    {'OrderID': 10301,
#     'ProductID': 56,
#     'Quantity': 20,
#     'UnitPrice': 30.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10302,
#   'OrderDate': '1996-09-10 00:00:00',
#   'RequiredDate': '1996-10-08 00:00:00',
#   'ShippedDate': '1996-10-09 00:00:00',
#   'ShipName': 'Suprêmes délices',
#   'ShipCountry': 'Belgium',
#   'ShipRegion': None,
#   'ShipAddress': 'Boulevard Tirou, 255',
#   'ShipPostalCode': 'B-6000',
#   'ShipCity': 'Charleroi',
#   'OrderDetails': [{'OrderID': 10302,
#     'ProductID': 17,
#     'Quantity': 40,
#     'UnitPrice': 31.2,
#     'Discount': 0.0},
#    {'OrderID': 10302,
#     'ProductID': 28,
#     'Quantity': 28,
#     'UnitPrice': 36.4,
#     'Discount': 0.0},
#    {'OrderID': 10302,
#     'ProductID': 43,
#     'Quantity': 12,
#     'UnitPrice': 36.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10303,
#   'OrderDate': '1996-09-11 00:00:00',
#   'RequiredDate': '1996-10-09 00:00:00',
#   'ShippedDate': '1996-09-18 00:00:00',
#   'ShipName': 'Godos Cocina Típica',
#   'ShipCountry': 'Spain',
#   'ShipRegion': None,
#   'ShipAddress': 'C/ Romero, 33',
#   'ShipPostalCode': '41101',
#   'ShipCity': 'Sevilla',
#   'OrderDetails': [{'OrderID': 10303,
#     'ProductID': 40,
#     'Quantity': 40,
#     'UnitPrice': 14.7,
#     'Discount': 0.1000000015},
#    {'OrderID': 10303,
#     'ProductID': 65,
#     'Quantity': 30,
#     'UnitPrice': 16.8,
#     'Discount': 0.1000000015},
#    {'OrderID': 10303,
#     'ProductID': 68,
#     'Quantity': 15,
#     'UnitPrice': 10.0,
#     'Discount': 0.1000000015}]},
#  {'OrderID': 10304,
#   'OrderDate': '1996-09-12 00:00:00',
#   'RequiredDate': '1996-10-10 00:00:00',
#   'ShippedDate': '1996-09-17 00:00:00',
#   'ShipName': 'Tortuga Restaurante',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Avda. Azteca 123',
#   'ShipPostalCode': '05033',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 10304,
#     'ProductID': 49,
#     'Quantity': 30,
#     'UnitPrice': 16.0,
#     'Discount': 0.0},
#    {'OrderID': 10304,
#     'ProductID': 59,
#     'Quantity': 10,
#     'UnitPrice': 44.0,
#     'Discount': 0.0},
#    {'OrderID': 10304,
#     'ProductID': 71,
#     'Quantity': 2,
#     'UnitPrice': 17.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10305,
#   'OrderDate': '1996-09-13 00:00:00',
#   'RequiredDate': '1996-10-11 00:00:00',
#   'ShippedDate': '1996-10-09 00:00:00',
#   'ShipName': 'Old World Delicatessen',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'AK',
#   'ShipAddress': '2743 Bering St.',
#   'ShipPostalCode': '99508',
#   'ShipCity': 'Anchorage',
#   'OrderDetails': [{'OrderID': 10305,
#     'ProductID': 18,
#     'Quantity': 25,
#     'UnitPrice': 50.0,
#     'Discount': 0.1000000015},
#    {'OrderID': 10305,
#     'ProductID': 29,
#     'Quantity': 25,
#     'UnitPrice': 99.0,
#     'Discount': 0.1000000015},
#    {'OrderID': 10305,
#     'ProductID': 39,
#     'Quantity': 30,
#     'UnitPrice': 14.4,
#     'Discount': 0.1000000015}]},
#  {'OrderID': 10306,
#   'OrderDate': '1996-09-16 00:00:00',
#   'RequiredDate': '1996-10-14 00:00:00',
#   'ShippedDate': '1996-09-23 00:00:00',
#   'ShipName': 'Romero y tomillo',
#   'ShipCountry': 'Spain',
#   'ShipRegion': None,
#   'ShipAddress': 'Gran Vía, 1',
#   'ShipPostalCode': '28001',
#   'ShipCity': 'Madrid',
#   'OrderDetails': [{'OrderID': 10306,
#     'ProductID': 30,
#     'Quantity': 10,
#     'UnitPrice': 20.7,
#     'Discount': 0.0},
#    {'OrderID': 10306,
#     'ProductID': 53,
#     'Quantity': 10,
#     'UnitPrice': 26.2,
#     'Discount': 0.0},
#    {'OrderID': 10306,
#     'ProductID': 54,
#     'Quantity': 5,
#     'UnitPrice': 5.9,
#     'Discount': 0.0}]},
#  {'OrderID': 10307,
#   'OrderDate': '1996-09-17 00:00:00',
#   'RequiredDate': '1996-10-15 00:00:00',
#   'ShippedDate': '1996-09-25 00:00:00',
#   'ShipName': 'Lonesome Pine Restaurant',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'OR',
#   'ShipAddress': '89 Chiaroscuro Rd.',
#   'ShipPostalCode': '97219',
#   'ShipCity': 'Portland',
#   'OrderDetails': [{'OrderID': 10307,
#     'ProductID': 62,
#     'Quantity': 10,
#     'UnitPrice': 39.4,
#     'Discount': 0.0},
#    {'OrderID': 10307,
#     'ProductID': 68,
#     'Quantity': 3,
#     'UnitPrice': 10.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10308,
#   'OrderDate': '1996-09-18 00:00:00',
#   'RequiredDate': '1996-10-16 00:00:00',
#   'ShippedDate': '1996-09-24 00:00:00',
#   'ShipName': 'Ana Trujillo Emparedados y helados',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Avda. de la Constitución 2222',
#   'ShipPostalCode': '05021',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 10308,
#     'ProductID': 69,
#     'Quantity': 1,
#     'UnitPrice': 28.8,
#     'Discount': 0.0},
#    {'OrderID': 10308,
#     'ProductID': 70,
#     'Quantity': 5,
#     'UnitPrice': 12.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10309,
#   'OrderDate': '1996-09-19 00:00:00',
#   'RequiredDate': '1996-10-17 00:00:00',
#   'ShippedDate': '1996-10-23 00:00:00',
#   'ShipName': 'Hungry Owl All-Night Grocers',
#   'ShipCountry': 'Ireland',
#   'ShipRegion': 'Co. Cork',
#   'ShipAddress': '8 Johnstown Road',
#   'ShipPostalCode': None,
#   'ShipCity': 'Cork',
#   'OrderDetails': [{'OrderID': 10309,
#     'ProductID': 4,
#     'Quantity': 20,
#     'UnitPrice': 17.6,
#     'Discount': 0.0},
#    {'OrderID': 10309,
#     'ProductID': 6,
#     'Quantity': 30,
#     'UnitPrice': 20.0,
#     'Discount': 0.0},
#    {'OrderID': 10309,
#     'ProductID': 42,
#     'Quantity': 2,
#     'UnitPrice': 11.2,
#     'Discount': 0.0},
#    {'OrderID': 10309,
#     'ProductID': 43,
#     'Quantity': 20,
#     'UnitPrice': 36.8,
#     'Discount': 0.0},
#    {'OrderID': 10309,
#     'ProductID': 71,
#     'Quantity': 3,
#     'UnitPrice': 17.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10310,
#   'OrderDate': '1996-09-20 00:00:00',
#   'RequiredDate': '1996-10-18 00:00:00',
#   'ShippedDate': '1996-09-27 00:00:00',
#   'ShipName': 'The Big Cheese',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'OR',
#   'ShipAddress': '89 Jefferson Way Suite 2',
#   'ShipPostalCode': '97201',
#   'ShipCity': 'Portland',
#   'OrderDetails': [{'OrderID': 10310,
#     'ProductID': 16,
#     'Quantity': 10,
#     'UnitPrice': 13.9,
#     'Discount': 0.0},
#    {'OrderID': 10310,
#     'ProductID': 62,
#     'Quantity': 5,
#     'UnitPrice': 39.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10311,
#   'OrderDate': '1996-09-20 00:00:00',
#   'RequiredDate': '1996-10-04 00:00:00',
#   'ShippedDate': '1996-09-26 00:00:00',
#   'ShipName': 'Du monde entier',
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': '67, rue des Cinquante Otages',
#   'ShipPostalCode': '44000',
#   'ShipCity': 'Nantes',
#   'OrderDetails': [{'OrderID': 10311,
#     'ProductID': 42,
#     'Quantity': 6,
#     'UnitPrice': 11.2,
#     'Discount': 0.0},
#    {'OrderID': 10311,
#     'ProductID': 69,
#     'Quantity': 7,
#     'UnitPrice': 28.8,
#     'Discount': 0.0}]},
#  {'OrderID': 10312,
#   'OrderDate': '1996-09-23 00:00:00',
#   'RequiredDate': '1996-10-21 00:00:00',
#   'ShippedDate': '1996-10-03 00:00:00',
#   'ShipName': 'Die Wandernde Kuh',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Adenauerallee 900',
#   'ShipPostalCode': '70563',
#   'ShipCity': 'Stuttgart',
#   'OrderDetails': [{'OrderID': 10312,
#     'ProductID': 28,
#     'Quantity': 4,
#     'UnitPrice': 36.4,
#     'Discount': 0.0},
#    {'OrderID': 10312,
#     'ProductID': 43,
#     'Quantity': 24,
#     'UnitPrice': 36.8,
#     'Discount': 0.0},
#    {'OrderID': 10312,
#     'ProductID': 53,
#     'Quantity': 20,
#     'UnitPrice': 26.2,
#     'Discount': 0.0},
#    {'OrderID': 10312,
#     'ProductID': 75,
#     'Quantity': 10,
#     'UnitPrice': 6.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10313,
#   'OrderDate': '1996-09-24 00:00:00',
#   'RequiredDate': '1996-10-22 00:00:00',
#   'ShippedDate': '1996-10-04 00:00:00',
#   'ShipName': 'QUICK-Stop',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Taucherstraße 10',
#   'ShipPostalCode': '01307',
#   'ShipCity': 'Cunewalde',
#   'OrderDetails': [{'OrderID': 10313,
#     'ProductID': 36,
#     'Quantity': 12,
#     'UnitPrice': 15.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10314,
#   'OrderDate': '1996-09-25 00:00:00',
#   'RequiredDate': '1996-10-23 00:00:00',
#   'ShippedDate': '1996-10-04 00:00:00',
#   'ShipName': 'Rattlesnake Canyon Grocery',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'NM',
#   'ShipAddress': '2817 Milton Dr.',
#   'ShipPostalCode': '87110',
#   'ShipCity': 'Albuquerque',
#   'OrderDetails': [{'OrderID': 10314,
#     'ProductID': 32,
#     'Quantity': 40,
#     'UnitPrice': 25.6,
#     'Discount': 0.1000000015},
#    {'OrderID': 10314,
#     'ProductID': 58,
#     'Quantity': 30,
#     'UnitPrice': 10.6,
#     'Discount': 0.1000000015},
#    {'OrderID': 10314,
#     'ProductID': 62,
#     'Quantity': 25,
#     'UnitPrice': 39.4,
#     'Discount': 0.1000000015}]},
#  {'OrderID': 10315,
#   'OrderDate': '1996-09-26 00:00:00',
#   'RequiredDate': '1996-10-24 00:00:00',
#   'ShippedDate': '1996-10-03 00:00:00',
#   'ShipName': 'Island Trading',
#   'ShipCountry': 'UK',
#   'ShipRegion': 'Isle of Wight',
#   'ShipAddress': 'Garden House Crowther Way',
#   'ShipPostalCode': 'PO31 7PJ',
#   'ShipCity': 'Cowes',
#   'OrderDetails': [{'OrderID': 10315,
#     'ProductID': 34,
#     'Quantity': 14,
#     'UnitPrice': 11.2,
#     'Discount': 0.0},
#    {'OrderID': 10315,
#     'ProductID': 70,
#     'Quantity': 30,
#     'UnitPrice': 12.0,
#     'Discount': 0.0}]},
#  {'OrderID': 10316,
#   'OrderDate': '1996-09-27 00:00:00',
#   'RequiredDate': '1996-10-25 00:00:00',
#   'ShippedDate': '1996-10-08 00:00:00',
#   'ShipName': 'Rattlesnake Canyon Grocery',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'NM',
#   'ShipAddress': '2817 Milton Dr.',
#   'ShipPostalCode': '87110',
#   'ShipCity': 'Albuquerque',
#   'OrderDetails': [{'OrderID': 10316,
#     'ProductID': 41,
#     'Quantity': 10,
#     'UnitPrice': 7.7,
#     'Discount': 0.0},
#    {'OrderID': 10316,
#     'ProductID': 62,
#     'Quantity': 70,
#     'UnitPrice': 39.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10317,
#   'OrderDate': '1996-09-30 00:00:00',
#   'RequiredDate': '1996-10-28 00:00:00',
#   'ShippedDate': '1996-10-10 00:00:00',
#   'ShipName': 'Lonesome Pine Restaurant',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'OR',
#   'ShipAddress': '89 Chiaroscuro Rd.',
#   'ShipPostalCode': '97219',
#   'ShipCity': 'Portland',
#   'OrderDetails': [{'OrderID': 10317,
#     'ProductID': 1,
#     'Quantity': 20,
#     'UnitPrice': 14.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10318,
#   'OrderDate': '1996-10-01 00:00:00',
#   'RequiredDate': '1996-10-29 00:00:00',
#   'ShippedDate': '1996-10-04 00:00:00',
#   'ShipName': 'Island Trading',
#   'ShipCountry': 'UK',
#   'ShipRegion': 'Isle of Wight',
#   'ShipAddress': 'Garden House Crowther Way',
#   'ShipPostalCode': 'PO31 7PJ',
#   'ShipCity': 'Cowes',
#   'OrderDetails': [{'OrderID': 10318,
#     'ProductID': 41,
#     'Quantity': 20,
#     'UnitPrice': 7.7,
#     'Discount': 0.0},
#    {'OrderID': 10318,
#     'ProductID': 76,
#     'Quantity': 6,
#     'UnitPrice': 14.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10319,
#   'OrderDate': '1996-10-02 00:00:00',
#   'RequiredDate': '1996-10-30 00:00:00',
#   'ShippedDate': '1996-10-11 00:00:00',
#   'ShipName': 'Tortuga Restaurante',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Avda. Azteca 123',
#   'ShipPostalCode': '05033',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 10319,
#     'ProductID': 17,
#     'Quantity': 8,
#     'UnitPrice': 31.2,
#     'Discount': 0.0},
#    {'OrderID': 10319,
#     'ProductID': 28,
#     'Quantity': 14,
#     'UnitPrice': 36.4,
#     'Discount': 0.0},
#    {'OrderID': 10319,
#     'ProductID': 76,
#     'Quantity': 30,
#     'UnitPrice': 14.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10320,
#   'OrderDate': '1996-10-03 00:00:00',
#   'RequiredDate': '1996-10-17 00:00:00',
#   'ShippedDate': '1996-10-18 00:00:00',
#   'ShipName': 'Wartian Herkku',
#   'ShipCountry': 'Finland',
#   'ShipRegion': None,
#   'ShipAddress': 'Torikatu 38',
#   'ShipPostalCode': '90110',
#   'ShipCity': 'Oulu',
#   'OrderDetails': [{'OrderID': 10320,
#     'ProductID': 71,
#     'Quantity': 30,
#     'UnitPrice': 17.2,
#     'Discount': 0.0}]},
#  {'OrderID': 10321,
#   'OrderDate': '1996-10-03 00:00:00',
#   'RequiredDate': '1996-10-31 00:00:00',
#   'ShippedDate': '1996-10-11 00:00:00',
#   'ShipName': 'Island Trading',
#   'ShipCountry': 'UK',
#   'ShipRegion': 'Isle of Wight',
#   'ShipAddress': 'Garden House Crowther Way',
#   'ShipPostalCode': 'PO31 7PJ',
#   'ShipCity': 'Cowes',
#   'OrderDetails': [{'OrderID': 10321,
#     'ProductID': 35,
#     'Quantity': 10,
#     'UnitPrice': 14.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10322,
#   'OrderDate': '1996-10-04 00:00:00',
#   'RequiredDate': '1996-11-01 00:00:00',
#   'ShippedDate': '1996-10-23 00:00:00',
#   'ShipName': 'Pericles Comidas clásicas',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Calle Dr. Jorge Cash 321',
#   'ShipPostalCode': '05033',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 10322,
#     'ProductID': 52,
#     'Quantity': 20,
#     'UnitPrice': 5.6,
#     'Discount': 0.0}]},
#  {'OrderID': 10323,
#   'OrderDate': '1996-10-07 00:00:00',
#   'RequiredDate': '1996-11-04 00:00:00',
#   'ShippedDate': '1996-10-14 00:00:00',
#   'ShipName': 'Königlich Essen',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Maubelstr. 90',
#   'ShipPostalCode': '14776',
#   'ShipCity': 'Brandenburg',
#   'OrderDetails': [{'OrderID': 10323,
#     'ProductID': 15,
#     'Quantity': 5,
#     'UnitPrice': 12.4,
#     'Discount': 0.0},
#    {'OrderID': 10323,
#     'ProductID': 25,
#     'Quantity': 4,
#     'UnitPrice': 11.2,
#     'Discount': 0.0},
#    {'OrderID': 10323,
#     'ProductID': 39,
#     'Quantity': 4,
#     'UnitPrice': 14.4,
#     'Discount': 0.0}]},
#  {'OrderID': 10324,
#   'OrderDate': '1996-10-08 00:00:00',
#   'RequiredDate': '1996-11-05 00:00:00',
#   'ShippedDate': '1996-10-10 00:00:00',
#   'ShipName': 'Save-a-lot Markets',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'ID',
#   'ShipAddress': '187 Suffolk Ln.',
#   'ShipPostalCode': '83720',
#   'ShipCity': 'Boise',
#   'OrderDetails': [{'OrderID': 10324,
#     'ProductID': 16,
#     'Quantity': 21,
#     'UnitPrice': 13.9,
#     'Discount': 0.150000006},
#    {'OrderID': 10324,
#     'ProductID': 35,
#     'Quantity': 70,
#     'UnitPrice': 14.4,
#     'Discount': 0.150000006},
#    {'OrderID': 10324,
#     'ProductID': 46,
#     'Quantity': 30,
#     'UnitPrice': 9.6,
#     'Discount': 0.0},
#    {'OrderID': 10324,
#     'ProductID': 59,
#     'Quantity': 40,
#     'UnitPrice': 44.0,
#     'Discount': 0.150000006},
#    {'OrderID': 10324,
#     'ProductID': 63,
# ...
#    {'OrderID': 11055,
#     'ProductID': 51,
#     'Quantity': 20,
#     'UnitPrice': 53.0,
#     'Discount': 0.0},
#    {'OrderID': 11055,
#     'ProductID': 57,
#     'Quantity': 20,
#     'UnitPrice': 19.5,
#     'Discount': 0.0}]},
#  {'OrderID': 11056,
#   'OrderDate': '1998-04-28 00:00:00',
#   'RequiredDate': '1998-05-12 00:00:00',
#   'ShippedDate': '1998-05-01 00:00:00',
#   'ShipName': 'Eastern Connection',
#   'ShipCountry': 'UK',
#   'ShipRegion': None,
#   'ShipAddress': '35 King George',
#   'ShipPostalCode': 'WX3 6FW',
#   'ShipCity': 'London',
#   'OrderDetails': [{'OrderID': 11056,
#     'ProductID': 7,
#     'Quantity': 40,
#     'UnitPrice': 30.0,
#     'Discount': 0.0},
#    {'OrderID': 11056,
#     'ProductID': 55,
#     'Quantity': 35,
#     'UnitPrice': 24.0,
#     'Discount': 0.0},
#    {'OrderID': 11056,
#     'ProductID': 60,
#     'Quantity': 50,
#     'UnitPrice': 34.0,
#     'Discount': 0.0}]},
#  {'OrderID': 11057,
#   'OrderDate': '1998-04-29 00:00:00',
#   'RequiredDate': '1998-05-27 00:00:00',
#   'ShippedDate': '1998-05-01 00:00:00',
#   'ShipName': 'North/South',
#   'ShipCountry': 'UK',
#   'ShipRegion': None,
#   'ShipAddress': 'South House 300 Queensbridge',
#   'ShipPostalCode': 'SW7 1RZ',
#   'ShipCity': 'London',
#   'OrderDetails': [{'OrderID': 11057,
#     'ProductID': 70,
#     'Quantity': 3,
#     'UnitPrice': 15.0,
#     'Discount': 0.0}]},
#  {'OrderID': 11058,
#   'OrderDate': '1998-04-29 00:00:00',
#   'RequiredDate': '1998-05-27 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Blauer See Delikatessen',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Forsterstr. 57',
#   'ShipPostalCode': '68306',
#   'ShipCity': 'Mannheim',
#   'OrderDetails': [{'OrderID': 11058,
#     'ProductID': 21,
#     'Quantity': 3,
#     'UnitPrice': 10.0,
#     'Discount': 0.0},
#    {'OrderID': 11058,
#     'ProductID': 60,
#     'Quantity': 21,
#     'UnitPrice': 34.0,
#     'Discount': 0.0},
#    {'OrderID': 11058,
#     'ProductID': 61,
#     'Quantity': 4,
#     'UnitPrice': 28.5,
#     'Discount': 0.0}]},
#  {'OrderID': 11059,
#   'OrderDate': '1998-04-29 00:00:00',
#   'RequiredDate': '1998-06-10 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Ricardo Adocicados',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'RJ',
#   'ShipAddress': 'Av. Copacabana, 267',
#   'ShipPostalCode': '02389-890',
#   'ShipCity': 'Rio de Janeiro',
#   'OrderDetails': [{'OrderID': 11059,
#     'ProductID': 13,
#     'Quantity': 30,
#     'UnitPrice': 6.0,
#     'Discount': 0.0},
#    {'OrderID': 11059,
#     'ProductID': 17,
#     'Quantity': 12,
#     'UnitPrice': 39.0,
#     'Discount': 0.0},
#    {'OrderID': 11059,
#     'ProductID': 60,
#     'Quantity': 35,
#     'UnitPrice': 34.0,
#     'Discount': 0.0}]},
#  {'OrderID': 11060,
#   'OrderDate': '1998-04-30 00:00:00',
#   'RequiredDate': '1998-05-28 00:00:00',
#   'ShippedDate': '1998-05-04 00:00:00',
#   'ShipName': 'Franchi S.p.A.',
#   'ShipCountry': 'Italy',
#   'ShipRegion': None,
#   'ShipAddress': 'Via Monte Bianco 34',
#   'ShipPostalCode': '10100',
#   'ShipCity': 'Torino',
#   'OrderDetails': [{'OrderID': 11060,
#     'ProductID': 60,
#     'Quantity': 4,
#     'UnitPrice': 34.0,
#     'Discount': 0.0},
#    {'OrderID': 11060,
#     'ProductID': 77,
#     'Quantity': 10,
#     'UnitPrice': 13.0,
#     'Discount': 0.0}]},
#  {'OrderID': 11061,
#   'OrderDate': '1998-04-30 00:00:00',
#   'RequiredDate': '1998-06-11 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Great Lakes Food Market',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'OR',
#   'ShipAddress': '2732 Baker Blvd.',
#   'ShipPostalCode': '97403',
#   'ShipCity': 'Eugene',
#   'OrderDetails': [{'OrderID': 11061,
#     'ProductID': 60,
#     'Quantity': 15,
#     'UnitPrice': 34.0,
#     'Discount': 0.0}]},
#  {'OrderID': 11062,
#   'OrderDate': '1998-04-30 00:00:00',
#   'RequiredDate': '1998-05-28 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Reggiani Caseifici',
#   'ShipCountry': 'Italy',
#   'ShipRegion': None,
#   'ShipAddress': 'Strada Provinciale 124',
#   'ShipPostalCode': '42100',
#   'ShipCity': 'Reggio Emilia',
#   'OrderDetails': [{'OrderID': 11062,
#     'ProductID': 53,
#     'Quantity': 10,
#     'UnitPrice': 32.8,
#     'Discount': 0.200000003},
#    {'OrderID': 11062,
#     'ProductID': 70,
#     'Quantity': 12,
#     'UnitPrice': 15.0,
#     'Discount': 0.200000003}]},
#  {'OrderID': 11063,
#   'OrderDate': '1998-04-30 00:00:00',
#   'RequiredDate': '1998-05-28 00:00:00',
#   'ShippedDate': '1998-05-06 00:00:00',
#   'ShipName': 'Hungry Owl All-Night Grocers',
#   'ShipCountry': 'Ireland',
#   'ShipRegion': 'Co. Cork',
#   'ShipAddress': '8 Johnstown Road',
#   'ShipPostalCode': None,
#   'ShipCity': 'Cork',
#   'OrderDetails': [{'OrderID': 11063,
#     'ProductID': 34,
#     'Quantity': 30,
#     'UnitPrice': 14.0,
#     'Discount': 0.0},
#    {'OrderID': 11063,
#     'ProductID': 40,
#     'Quantity': 40,
#     'UnitPrice': 18.4,
#     'Discount': 0.1000000015},
#    {'OrderID': 11063,
#     'ProductID': 41,
#     'Quantity': 30,
#     'UnitPrice': 9.65,
#     'Discount': 0.1000000015}]},
#  {'OrderID': 11064,
#   'OrderDate': '1998-05-01 00:00:00',
#   'RequiredDate': '1998-05-29 00:00:00',
#   'ShippedDate': '1998-05-04 00:00:00',
#   'ShipName': 'Save-a-lot Markets',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'ID',
#   'ShipAddress': '187 Suffolk Ln.',
#   'ShipPostalCode': '83720',
#   'ShipCity': 'Boise',
#   'OrderDetails': [{'OrderID': 11064,
#     'ProductID': 17,
#     'Quantity': 77,
#     'UnitPrice': 39.0,
#     'Discount': 0.1000000015},
#    {'OrderID': 11064,
#     'ProductID': 41,
#     'Quantity': 12,
#     'UnitPrice': 9.65,
#     'Discount': 0.0},
#    {'OrderID': 11064,
#     'ProductID': 53,
#     'Quantity': 25,
#     'UnitPrice': 32.8,
#     'Discount': 0.1000000015},
#    {'OrderID': 11064,
#     'ProductID': 55,
#     'Quantity': 4,
#     'UnitPrice': 24.0,
#     'Discount': 0.1000000015},
#    {'OrderID': 11064,
#     'ProductID': 68,
#     'Quantity': 55,
#     'UnitPrice': 12.5,
#     'Discount': 0.0}]},
#  {'OrderID': 11065,
#   'OrderDate': '1998-05-01 00:00:00',
#   'RequiredDate': '1998-05-29 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'LILA-Supermercado',
#   'ShipCountry': 'Venezuela',
#   'ShipRegion': 'Lara',
#   'ShipAddress': 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo',
#   'ShipPostalCode': '3508',
#   'ShipCity': 'Barquisimeto',
#   'OrderDetails': [{'OrderID': 11065,
#     'ProductID': 30,
#     'Quantity': 4,
#     'UnitPrice': 25.89,
#     'Discount': 0.25},
#    {'OrderID': 11065,
#     'ProductID': 54,
#     'Quantity': 20,
#     'UnitPrice': 7.45,
#     'Discount': 0.25}]},
#  {'OrderID': 11066,
#   'OrderDate': '1998-05-01 00:00:00',
#   'RequiredDate': '1998-05-29 00:00:00',
#   'ShippedDate': '1998-05-04 00:00:00',
#   'ShipName': 'White Clover Markets',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'WA',
#   'ShipAddress': '1029 - 12th Ave. S.',
#   'ShipPostalCode': '98124',
#   'ShipCity': 'Seattle',
#   'OrderDetails': [{'OrderID': 11066,
#     'ProductID': 16,
#     'Quantity': 3,
#     'UnitPrice': 17.45,
#     'Discount': 0.0},
#    {'OrderID': 11066,
#     'ProductID': 19,
#     'Quantity': 42,
#     'UnitPrice': 9.2,
#     'Discount': 0.0},
#    {'OrderID': 11066,
#     'ProductID': 34,
#     'Quantity': 35,
#     'UnitPrice': 14.0,
#     'Discount': 0.0}]},
#  {'OrderID': 11067,
#   'OrderDate': '1998-05-04 00:00:00',
#   'RequiredDate': '1998-05-18 00:00:00',
#   'ShippedDate': '1998-05-06 00:00:00',
#   'ShipName': 'Drachenblut Delikatessen',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Walserweg 21',
#   'ShipPostalCode': '52066',
#   'ShipCity': 'Aachen',
#   'OrderDetails': [{'OrderID': 11067,
#     'ProductID': 41,
#     'Quantity': 9,
#     'UnitPrice': 9.65,
#     'Discount': 0.0}]},
#  {'OrderID': 11068,
#   'OrderDate': '1998-05-04 00:00:00',
#   'RequiredDate': '1998-06-01 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Queen Cozinha',
#   'ShipCountry': 'Brazil',
#   'ShipRegion': 'SP',
#   'ShipAddress': 'Alameda dos Canàrios, 891',
#   'ShipPostalCode': '05487-020',
#   'ShipCity': 'Sao Paulo',
#   'OrderDetails': [{'OrderID': 11068,
#     'ProductID': 28,
#     'Quantity': 8,
#     'UnitPrice': 45.6,
#     'Discount': 0.150000006},
#    {'OrderID': 11068,
#     'ProductID': 43,
#     'Quantity': 36,
#     'UnitPrice': 46.0,
#     'Discount': 0.150000006},
#    {'OrderID': 11068,
#     'ProductID': 77,
#     'Quantity': 28,
#     'UnitPrice': 13.0,
#     'Discount': 0.150000006}]},
#  {'OrderID': 11069,
#   'OrderDate': '1998-05-04 00:00:00',
#   'RequiredDate': '1998-06-01 00:00:00',
#   'ShippedDate': '1998-05-06 00:00:00',
#   'ShipName': 'Tortuga Restaurante',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Avda. Azteca 123',
#   'ShipPostalCode': '05033',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 11069,
#     'ProductID': 39,
#     'Quantity': 20,
#     'UnitPrice': 18.0,
#     'Discount': 0.0}]},
#  {'OrderID': 11070,
#   'OrderDate': '1998-05-05 00:00:00',
#   'RequiredDate': '1998-06-02 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Lehmanns Marktstand',
#   'ShipCountry': 'Germany',
#   'ShipRegion': None,
#   'ShipAddress': 'Magazinweg 7',
#   'ShipPostalCode': '60528',
#   'ShipCity': 'Frankfurt a.M.',
#   'OrderDetails': [{'OrderID': 11070,
#     'ProductID': 1,
#     'Quantity': 40,
#     'UnitPrice': 18.0,
#     'Discount': 0.150000006},
#    {'OrderID': 11070,
#     'ProductID': 2,
#     'Quantity': 20,
#     'UnitPrice': 19.0,
#     'Discount': 0.150000006},
#    {'OrderID': 11070,
#     'ProductID': 16,
#     'Quantity': 30,
#     'UnitPrice': 17.45,
#     'Discount': 0.150000006},
#    {'OrderID': 11070,
#     'ProductID': 31,
#     'Quantity': 20,
#     'UnitPrice': 12.5,
#     'Discount': 0.0}]},
#  {'OrderID': 11071,
#   'OrderDate': '1998-05-05 00:00:00',
#   'RequiredDate': '1998-06-02 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'LILA-Supermercado',
#   'ShipCountry': 'Venezuela',
#   'ShipRegion': 'Lara',
#   'ShipAddress': 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo',
#   'ShipPostalCode': '3508',
#   'ShipCity': 'Barquisimeto',
#   'OrderDetails': [{'OrderID': 11071,
#     'ProductID': 7,
#     'Quantity': 15,
#     'UnitPrice': 30.0,
#     'Discount': 0.0500000007},
#    {'OrderID': 11071,
#     'ProductID': 13,
#     'Quantity': 10,
#     'UnitPrice': 6.0,
#     'Discount': 0.0500000007}]},
#  {'OrderID': 11072,
#   'OrderDate': '1998-05-05 00:00:00',
#   'RequiredDate': '1998-06-02 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Ernst Handel',
#   'ShipCountry': 'Austria',
#   'ShipRegion': None,
#   'ShipAddress': 'Kirchgasse 6',
#   'ShipPostalCode': '8010',
#   'ShipCity': 'Graz',
#   'OrderDetails': [{'OrderID': 11072,
#     'ProductID': 2,
#     'Quantity': 8,
#     'UnitPrice': 19.0,
#     'Discount': 0.0},
#    {'OrderID': 11072,
#     'ProductID': 41,
#     'Quantity': 40,
#     'UnitPrice': 9.65,
#     'Discount': 0.0},
#    {'OrderID': 11072,
#     'ProductID': 50,
#     'Quantity': 22,
#     'UnitPrice': 16.25,
#     'Discount': 0.0},
#    {'OrderID': 11072,
#     'ProductID': 64,
#     'Quantity': 130,
#     'UnitPrice': 33.25,
#     'Discount': 0.0}]},
#  {'OrderID': 11073,
#   'OrderDate': '1998-05-05 00:00:00',
#   'RequiredDate': '1998-06-02 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Pericles Comidas clásicas',
#   'ShipCountry': 'Mexico',
#   'ShipRegion': None,
#   'ShipAddress': 'Calle Dr. Jorge Cash 321',
#   'ShipPostalCode': '05033',
#   'ShipCity': 'México D.F.',
#   'OrderDetails': [{'OrderID': 11073,
#     'ProductID': 11,
#     'Quantity': 10,
#     'UnitPrice': 21.0,
#     'Discount': 0.0},
#    {'OrderID': 11073,
#     'ProductID': 24,
#     'Quantity': 20,
#     'UnitPrice': 4.5,
#     'Discount': 0.0}]},
#  {'OrderID': 11074,
#   'OrderDate': '1998-05-06 00:00:00',
#   'RequiredDate': '1998-06-03 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Simons bistro',
#   'ShipCountry': 'Denmark',
#   'ShipRegion': None,
#   'ShipAddress': 'Vinbæltet 34',
#   'ShipPostalCode': '1734',
#   'ShipCity': 'Kobenhavn',
#   'OrderDetails': [{'OrderID': 11074,
#     'ProductID': 16,
#     'Quantity': 14,
#     'UnitPrice': 17.45,
#     'Discount': 0.0500000007}]},
#  {'OrderID': 11075,
#   'OrderDate': '1998-05-06 00:00:00',
#   'RequiredDate': '1998-06-03 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Richter Supermarkt',
#   'ShipCountry': 'Switzerland',
#   'ShipRegion': None,
#   'ShipAddress': 'Starenweg 5',
#   'ShipPostalCode': '1204',
#   'ShipCity': 'Genève',
#   'OrderDetails': [{'OrderID': 11075,
#     'ProductID': 2,
#     'Quantity': 10,
#     'UnitPrice': 19.0,
#     'Discount': 0.150000006},
#    {'OrderID': 11075,
#     'ProductID': 46,
#     'Quantity': 30,
#     'UnitPrice': 12.0,
#     'Discount': 0.150000006},
#    {'OrderID': 11075,
#     'ProductID': 76,
#     'Quantity': 2,
#     'UnitPrice': 18.0,
#     'Discount': 0.150000006}]},
#  {'OrderID': 11076,
#   'OrderDate': '1998-05-06 00:00:00',
#   'RequiredDate': '1998-06-03 00:00:00',
#   'ShippedDate': None,
#   'ShipName': "Bon app'",
#   'ShipCountry': 'France',
#   'ShipRegion': None,
#   'ShipAddress': '12, rue des Bouchers',
#   'ShipPostalCode': '13008',
#   'ShipCity': 'Marseille',
#   'OrderDetails': [{'OrderID': 11076,
#     'ProductID': 6,
#     'Quantity': 20,
#     'UnitPrice': 25.0,
#     'Discount': 0.25},
#    {'OrderID': 11076,
#     'ProductID': 14,
#     'Quantity': 20,
#     'UnitPrice': 23.25,
#     'Discount': 0.25},
#    {'OrderID': 11076,
#     'ProductID': 19,
#     'Quantity': 10,
#     'UnitPrice': 9.2,
#     'Discount': 0.25}]},
#  {'OrderID': 11077,
#   'OrderDate': '1998-05-06 00:00:00',
#   'RequiredDate': '1998-06-03 00:00:00',
#   'ShippedDate': None,
#   'ShipName': 'Rattlesnake Canyon Grocery',
#   'ShipCountry': 'USA',
#   'ShipRegion': 'NM',
#   'ShipAddress': '2817 Milton Dr.',
#   'ShipPostalCode': '87110',
#   'ShipCity': 'Albuquerque',
#   'OrderDetails': [{'OrderID': 11077,
#     'ProductID': 2,
#     'Quantity': 24,
#     'UnitPrice': 19.0,
#     'Discount': 0.200000003},
#    {'OrderID': 11077,
#     'ProductID': 3,
#     'Quantity': 4,
#     'UnitPrice': 10.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 4,
#     'Quantity': 1,
#     'UnitPrice': 22.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 6,
#     'Quantity': 1,
#     'UnitPrice': 25.0,
#     'Discount': 0.0199999996},
#    {'OrderID': 11077,
#     'ProductID': 7,
#     'Quantity': 1,
#     'UnitPrice': 30.0,
#     'Discount': 0.0500000007},
#    {'OrderID': 11077,
#     'ProductID': 8,
#     'Quantity': 2,
#     'UnitPrice': 40.0,
#     'Discount': 0.1000000015},
#    {'OrderID': 11077,
#     'ProductID': 10,
#     'Quantity': 1,
#     'UnitPrice': 31.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 12,
#     'Quantity': 2,
#     'UnitPrice': 38.0,
#     'Discount': 0.0500000007},
#    {'OrderID': 11077,
#     'ProductID': 13,
#     'Quantity': 4,
#     'UnitPrice': 6.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 14,
#     'Quantity': 1,
#     'UnitPrice': 23.25,
#     'Discount': 0.0299999993},
#    {'OrderID': 11077,
#     'ProductID': 16,
#     'Quantity': 2,
#     'UnitPrice': 17.45,
#     'Discount': 0.0299999993},
#    {'OrderID': 11077,
#     'ProductID': 20,
#     'Quantity': 1,
#     'UnitPrice': 81.0,
#     'Discount': 0.0399999991},
#    {'OrderID': 11077,
#     'ProductID': 23,
#     'Quantity': 2,
#     'UnitPrice': 9.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 32,
#     'Quantity': 1,
#     'UnitPrice': 32.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 39,
#     'Quantity': 2,
#     'UnitPrice': 18.0,
#     'Discount': 0.0500000007},
#    {'OrderID': 11077,
#     'ProductID': 41,
#     'Quantity': 3,
#     'UnitPrice': 9.65,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 46,
#     'Quantity': 3,
#     'UnitPrice': 12.0,
#     'Discount': 0.0199999996},
#    {'OrderID': 11077,
#     'ProductID': 52,
#     'Quantity': 2,
#     'UnitPrice': 7.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 55,
#     'Quantity': 2,
#     'UnitPrice': 24.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 60,
#     'Quantity': 2,
#     'UnitPrice': 34.0,
#     'Discount': 0.0599999987},
#    {'OrderID': 11077,
#     'ProductID': 64,
#     'Quantity': 2,
#     'UnitPrice': 33.25,
#     'Discount': 0.0299999993},
#    {'OrderID': 11077,
#     'ProductID': 66,
#     'Quantity': 1,
#     'UnitPrice': 17.0,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 73,
#     'Quantity': 2,
#     'UnitPrice': 15.0,
#     'Discount': 0.0099999998},
#    {'OrderID': 11077,
#     'ProductID': 75,
#     'Quantity': 4,
#     'UnitPrice': 7.75,
#     'Discount': 0.0},
#    {'OrderID': 11077,
#     'ProductID': 77,
#     'Quantity': 2,
#     'UnitPrice': 13.0,
#     'Discount': 0.0}]}]

# %%
collection.delete_many({})
# Out:
# DeleteResult({'n': 830, 'electionId': ObjectId('7fffffff00000000000001eb'), 'opTime': {'ts': Timestamp(1738831998, 107), 't': 491}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(
94'), ObjectId('67a47884acc37b5ba789ba95'), ObjectId('67a47884acc37b5ba789ba96'), ObjectId('67a47884acc37b5ba789ba97'), ObjectId('67a47884acc37b5ba789ba98'), ObjectId('67a47884acc37b5ba789ba99'), ObjectId('67a47884acc37b5ba789ba9a'), ObjectId('67a47884acc37b5ba789ba9b'), ObjectId('67a47884acc37b5ba789ba9c'), ObjectId('67a47884acc37b5ba789ba9d'), ObjectId('67a47884acc37b5ba789ba9e'), ObjectId('67a47884acc37b5ba789ba9f'), ObjectId('67a47884acc37b5ba789baa0'), ObjectId('67a47884acc37b5ba789baa1'), ObjectId('67a47884acc37b5ba789baa2'), ObjectId('67a47884acc37b5ba789baa3'), ObjectId('67a47884acc37b5ba789baa4'), ObjectId('67a47884acc37b5ba789baa5'), ObjectId('67a47884acc37b5ba789baa6'), ObjectId('67a47884acc37b5ba789baa7'), ObjectId('67a47884acc37b5ba789baa8'), ObjectId('67a47884acc37b5ba789baa9'), ObjectId('67a47884acc37b5ba789baaa'), ObjectId('67a47884acc37b5ba789baab'), ObjectId('67a47884acc37b5ba789baac'), ObjectId('67a47884acc37b5ba789baad'), ObjectId('67a47884acc37b5ba789baae'), ObjectId('67a47884acc37b5ba789baaf'), ObjectId('67a47884acc37b5ba789bab0'), ObjectId('67a47884acc37b5ba789bab1'), ObjectId('67a47884acc37b5ba789bab2'), ObjectId('67a47884acc37b5ba789bab3'), ObjectId('67a47884acc37b5ba789bab4'), ObjectId('67a47884acc37b5ba789bab5'), ObjectId('67a47884acc37b5ba789bab6'), ObjectId('67a47884acc37b5ba789bab7'), ObjectId('67a47884acc37b5ba789bab8'), ObjectId('67a47884acc37b5ba789bab9'), ObjectId('67a47884acc37b5ba789baba'), ObjectId('67a47884acc37b5ba789babb'), ObjectId('67a47884acc37b5ba789babc'), ObjectId('67a47884acc37b5ba789babd'), ObjectId('67a47884acc37b5ba789babe'), ObjectId('67a47884acc37b5ba789babf'), ObjectId('67a47884acc37b5ba789bac0'), ObjectId('67a47884acc37b5ba789bac1'), ObjectId('67a47884acc37b5ba789bac2'), ObjectId('67a47884acc37b5ba789bac3'), ObjectId('67a47884acc37b5ba789bac4'), ObjectId('67a47884acc37b5ba789bac5'), ObjectId('67a47884acc37b5ba789bac6'), ObjectId('67a47884acc37b5ba789bac7'), ObjectId('67a47884acc37b5ba789bac8'), ObjectId('67a47884acc37b5ba789bac9'), ObjectId('67a47884acc37b5ba789 ...

# %%
results = collection.find()

# %%
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('67a47884acc37b5ba789ba62'), 'OrderID': 10248, 'OrderDate': '1996-07-04 00:00:00', 'RequiredDate': '1996-08-01 00:00:00', 'ShippedDate': '1996-07-16 00:00:00', 'ShipName': 'Vins et alcools Chevalier', 'ShipCountry': 'France', 'ShipRegion': None, 'ShipAddress': "59 rue de l'Abbaye", 'ShipPostalCode': '51100', 'ShipCity': 'Reims', 'OrderDetails': [{'OrderID': 10248, 'ProductID': 11, 'Quantity': 12, 'UnitPrice': 14.0, 'Discount': 0.0}, {'OrderID': 10248, 'ProductID': 42, 'Quantity': 10, 'UnitPrice': 9.8, 'Discount': 0.0}, {'OrderID': 10248, 'ProductID': 72, 'Quantity': 5, 'UnitPrice': 34.8, 'Discount': 0.0}]}
# {'_id': ObjectId('67a47884acc37b5ba789
]}
# {'_id': ObjectId('67a47884acc37b5ba789bd9a'), 'OrderID': 11072, 'OrderDate': '1998-05-05 00:00:00', 'RequiredDate': '1998-06-02 00:00:00', 'ShippedDate': None, 'ShipName': 'Ernst Handel', 'ShipCountry': 'Austria', 'ShipRegion': None, 'ShipAddress': 'Kirchgasse 6', 'ShipPostalCode': '8010', 'ShipCity': 'Graz', 'OrderDetails': [{'OrderID': 11072, 'ProductID': 2, 'Quantity': 8, 'UnitPrice': 19.0, 'Discount': 0.0}, {'OrderID': 11072, 'ProductID': 41, 'Quantity': 40, 'UnitPrice': 9.65, 'Discount': 0.0}, {'OrderID': 11072, 'ProductID': 50, 'Quantity': 22, 'UnitPrice': 16.25, 'Discount': 0.0}, {'OrderID': 11072, 'ProductID': 64, 'Quantity': 130, 'UnitPrice': 33.25, 'Discount': 0.0}]}
# {'_id': ObjectId('67a47884acc37b5ba789bd9b'), 'OrderID': 11073, 'OrderDate': '1998-05-05 00:00:00', 'RequiredDate': '1998-06-02 00:00:00', 'ShippedDate': None, 'ShipName': 'Pericles Comidas clásicas', 'ShipCountry': 'Mexico', 'ShipRegion': None, 'ShipAddress': 'Calle Dr. Jorge Cash 321', 'ShipPostalCode': '05033', 'ShipCity': 'México D.F.', 'OrderDetails': [{'OrderID': 11073, 'ProductID': 11, 'Quantity': 10, 'UnitPrice': 21.0, 'Discount': 0.0}, {'OrderID': 11073, 'ProductID': 24, 'Quantity': 20, 'UnitPrice': 4.5, 'Discount': 0.0}]}
# {'_id': ObjectId('67a47884acc37b5ba789bd9c'), 'OrderID': 11074, 'OrderDate': '1998-05-06 00:00:00', 'RequiredDate': '1998-06-03 00:00:00', 'ShippedDate': None, 'ShipName': 'Simons bistro', 'ShipCountry': 'Denmark', 'ShipRegion': None, 'ShipAddress': 'Vinbæltet 34', 'ShipPostalCode': '1734', 'ShipCity': 'Kobenhavn', 'OrderDetails': [{'OrderID': 11074, 'ProductID': 16, 'Quantity': 14, 'UnitPrice': 17.45, 'Discount': 0.0500000007}]}
# {'_id': ObjectId('67a47884acc37b5ba789bd9d'), 'OrderID': 11075, 'OrderDate': '1998-05-06 00:00:00', 'RequiredDate': '1998-06-03 00:00:00', 'ShippedDate': None, 'ShipName': 'Richter Supermarkt', 'ShipCountry': 'Switzerland', 'ShipRegion': None, 'ShipAddress': 'Starenweg 5', 'ShipPostalCode': '1204', 'ShipCity': 'Genève', 'OrderDetails': [{'OrderID': 11075, 'ProductID': 2, 'Quantity': 10, 'UnitPrice': 19.0, 'Discount': 0.150000006}, {'OrderID': 11075, 'ProductID': 46, 'Quantity': 30, 'UnitPrice': 12.0, 'Discount': 0.150000006}, {'OrderID': 11075, 'ProductID': 76, 'Quantity': 2, 'UnitPrice': 18.0, 'Discount': 0.150000006}]}
# {'_id': ObjectId('67a47884acc37b5ba789bd9e'), 'OrderID': 11076, 'OrderDate': '1998-05-06 00:00:00', 'RequiredDate': '1998-06-03 00:00:00', 'ShippedDate': None, 'ShipName': "Bon app'", 'ShipCountry': 'France', 'ShipRegion': None, 'ShipAddress': '12, rue des Bouchers', 'ShipPostalCode': '13008', 'ShipCity': 'Marseille', 'OrderDetails': [{'OrderID': 11076, 'ProductID': 6, 'Quantity': 20, 'UnitPrice': 25.0, 'Discount': 0.25}, {'OrderID': 11076, 'ProductID': 14, 'Quantity': 20, 'UnitPrice': 23.25, 'Discount': 0.25}, {'OrderID': 11076, 'ProductID': 19, 'Quantity': 10, 'UnitPrice': 9.2, 'Discount': 0.25}]}
# %% [markdown]
# ### Några ord om duplicerad data
#
# Eftersom vi har en `ProductID`-kolumn i `OrderDetails` skulle vi också kunna lägga till `Product`-datan till varje `OrderDetail`. Det här är lite tvärtom mot hur vi tänker med relationella databaser där vi inte vill spara samma data flera gånger utan vill normalisera datan i så hög form som möjligt.
#
# I dokumentdatabaser är det helt ok att ha icke-normaliserad data under vissa förutsättningar. Databasen är gjord för att läsa nästlad data snabbt så om vi inte har alltför många nivåer.
#
# Den största risken med duplicerad data är om vi uppdaterar något "längre upp" i databasen. Om vi ändrar pris på en produkt måste vi se till att nya `OrderDetail`-dokument får med sig den ändringen.
#
# MongoDB har lösningar på hur man kan se till att duplicerad data håller sig uppdaterad.

# %% [markdown]
# ### Queries

# %% [markdown]
# Vi kan använda *Aggregations*-läget i MongoDB Atlas för att arbeta oss fram till vårt resultat. Sedan kan vi klistra in det i en cell och köra det från vår notebook.

# %%
total_sales_by_country = collection.aggregate([
    {
        '$unwind': {
            'path': '$OrderDetails'
        }
    }, {
        '$group': {
            '_id': '$ShipCountry', 
            'totalSalesAmount': {
                '$sum': {
                    '$multiply': [
                        '$OrderDetails.UnitPrice', '$OrderDetails.Quantity'
                    ]
                }
            }
        }
    }, {
        '$sort': {
            'totalSalesAmount': -1
        }
    }, {
        '$project': {
            'Country': '$_id', 
            'totalSalesAmount': '$totalSalesAmount'
        }
    }
])

# %%
[res for res in total_sales_by_country]
# Out:
# [{'_id': 'USA', 'Country': 'USA', 'totalSalesAmount': 263566.98},
#  {'_id': 'Germany', 'Country': 'Germany', 'totalSalesAmount': 244640.63},
#  {'_id': 'Austria', 'Country': 'Austria', 'totalSalesAmount': 139496.63},
#  {'_id': 'Brazil', 'Country': 'Brazil', 'totalSalesAmount': 114968.48},
#  {'_id': 'France', 'Country': 'France', 'totalSalesAmount': 85498.76},
#  {'_id': 'Venezuela', 'Country': 'Venezuela', 'totalSalesAmount': 60814.89},
#  {'_id': 'UK', 'Country': 'UK', 'totalSalesAmount': 60616.51},
#  {'_id': 'Sweden', 'Country': 'Sweden', 'totalSalesAmount': 59523.7},
#  {'_id': 'Ireland', 'Country': 'Ireland', 'totalSalesAmount': 57317.39},
#  {'_id': 'Canada', 'Country': 'Canada', 'totalSalesAmount': 55334.1},
#  {'_id': 'Belgium', 'Country': 'Belgium', 'totalSalesAmount': 35134.98},
#  {'_id': 'Denmark', 'Country': 'Denmark', 'totalSalesAmount': 34782.25},
#  {'_id': 'Switzerland', 'Country': 'Switzerland', 'totalSalesAmount': 32919.5},
#  {'_id': 'Mexico', 'Country': 'Mexico', 'totalSalesAmount': 24073.45},
#  {'_id': 'Finland', 'Country': 'Finland', 'totalSalesAmount': 19778.45},
#  {'_id': 'Spain', 'Country': 'Spain', 'totalSalesAmount': 19431.89},
#  {'_id': 'Italy', 'Country': 'Italy', 'totalSalesAmount': 16705.15},
#  {'_id': 'Portugal', 'Country': 'Portugal', 'totalSalesAmount': 12468.65},
#  {'_id': 'Argentina', 'Country': 'Argentina', 'totalSalesAmount': 8119.1},
#  {'_id': 'Norway', 'Country': 'Norway', 'totalSalesAmount': 5735.15},
#  {'_id': 'Poland', 'Country': 'Poland', 'totalSalesAmount': 3531.95}]

# %%
total_quantity_by_address = collection.aggregate([
    {
        '$unwind': {
            'path': '$OrderDetails'
        }
    }, {
        '$group': {
            '_id': '$ShipAddress', 
            'totalQuantity': {
                '$sum': '$OrderDetails.Quantity'
            }
        }
    }, {
        '$sort': {
            'totalQuantity': -1
        }
    }
])

# %%
for result in total_quantity_by_address:
    print(result)
# Out:
# {'_id': '187 Suffolk Ln.', 'totalQuantity': 4958}
# {'_id': 'Kirchgasse 6', 'totalQuantity': 4543}
# {'_id': 'Taucherstraße 10', 'totalQuantity': 3961}
# {'_id': '8 Johnstown Road', 'totalQuantity': 1684}
# {'_id': 'Berliner Platz 43', 'totalQuantity': 1525}
# {'_id': '2817 Milton Dr.', 'totalQuantity': 1383}
# {'_id': 'Åkergatan 24', 'totalQuantity': 1234}
# {'_id': 'Carrera 22 con Ave. Carlos Soublette #8-35', 'totalQuantity': 1096}
# {'_id': 'Boulevard Tirou, 255', 'totalQuantity': 1072}
# {'_id': '1029 - 12th Ave. S.', 'totalQuantity': 1063}
# {'_id': 'Alameda dos Canàrios, 891', 'totalQuantity': 1031}
# {'_id': 'Berguvsvägen  8', 'totalQuantity': 1001}
# {'_id': '12, rue des Bouchers', 'totalQuantity': 980}
# {'_id': 'Ave. 5 de Mayo Porlamar', 'totalQuantity': 970}
# {'_id': '43 rue St. Laurent', 'totalQuantity': 966}
# {'_id': '23 Tsawassen Blvd.', 'totalQuantity': 956}
# {'_id': 'Maubelstr. 90', 'totalQuantity': 903}
# {'_id': 'Rua do Paço, 67', 'totalQuantity': 839}
# {'_id': 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'totalQuantity': 836}
# {'_id': '90 Wadhurst Rd.', 'totalQuantity': 818}
# {'_id': 'Starenweg 5', 'totalQuantity': 810}
# {'_id': 'Magazinweg 7', 'totalQuantity': 794}
# {'_id': 'Smagsloget 45', 'totalQuantity': 792}
# {'_id': 'Torikatu 38', 'totalQuantity': 737}
# {'_id': '24, place Kléber', 'totalQuantity': 666}
# {'_id': 'Av. Copacabana, 267', 'totalQuantity': 660}
# {'_id': 'Brook Farm Stratford St. Mary', 'totalQuantity': 650}
# {'_id': 'Mehrheimerstr. 369', 'totalQuantity': 639}
# {'_id': 'Geislweg 14', 'totalQuantity': 624}
# {'_id': '2743 Bering St.', 'totalQuantity': 603}
# {'_id': '35 King George', 'totalQuantity': 569}
# {'_id': 'Adenauerallee 900', 'totalQuantity': 492}
# {'_id': 'Hauptstr. 31', 'totalQuantity': 465}
# {'_id': '1 rue Alsace-Lorraine', 'totalQuantity': 442}
# {'_id': '2, rue du Commerce', 'totalQuantity': 434}
# {'_id': 'Via Ludovico il Moro 22', 'totalQuantity': 433}
# {'_id': 'C/ Romero, 33', 'totalQuantity': 395}
# {'_id': 'Rua da Panificadora, 12', 'totalQuantity': 394}
# {'_id': 'Avda. Azteca 123', 'totalQuantity': 384}
# {'_id': 'Vinbæltet 34', 'totalQuantity': 378}
# {'_id': 'Mataderos  2312', 'totalQuantity': 359}
# {'_id': 'Rua Orós, 92', 'totalQuantity': 357}
# {'_id': '184, chaussée de Tournai', 'totalQuantity': 354}
# {'_id': 'Jardim das rosas n. 32', 'totalQuantity': 349}
# {'_id': '2732 Baker Blvd.', 'totalQuantity': 345}
# {'_id': 'Strada Provinciale 124', 'totalQuantity': 335}
# {'_id': 'P.O. Box 555', 'totalQuantity': 327}
# {'_id': 'Rue Joseph-Bens 532', 'totalQuantity': 320}
# {'_id': 'Av. Brasil, 442', 'totalQuantity': 315}
# {'_id': 'Garden House Crowther Way', 'totalQuantity': 295}
# {'_id': 'Fauntleroy Circus', 'totalQuantity': 293}
# {'_id': 'Rua do Mercado, 12', 'totalQuantity': 267}
# {'_id': 'Luisenstr. 48', 'totalQuantity': 253}
# {'_id': 'Av. Inês de Castro, 414', 'totalQuantity': 251}
# {'_id': 'Calle Dr. Jorge Cash 321', 'totalQuantity': 208}
# {'_id': 'ul. Filtrowa 68', 'totalQuantity': 205}
# {'_id': 'C/ Araquil, 67', 'totalQuantity': 190}
# {'_id': 'Estrada da saúde n. 58', 'totalQuantity': 184}
# {'_id': '87 Polk St. Suite 5', 'totalQuantity': 181}
# {'_id': 'Obere Str. 57', 'totalQuantity': 174}
# {'_id': 'Heerstr. 22', 'totalQuantity': 172}
# {'_id': 'Erling Skakkes gate 78', 'totalQuantity': 161}
# {'_id': 'Walserweg 21', 'totalQuantity': 160}
# {'_id': 'Keskuskatu 45', 'totalQuantity': 148}
# {'_id': 'Forsterstr. 57', 'totalQuantity': 140}
# {'_id': '89 Chiaroscuro Rd.', 'totalQuantity': 134}
# {'_id': 'Av. dos Lusíadas, 23', 'totalQuantity': 133}
# {'_id': 'Ing. Gustavo Moncada 8585 Piso 20-A', 'totalQuantity': 132}
# {'_id': 'City Center Plaza 516 Main St.', 'totalQuantity': 122}
# {'_id': 'Cerrito 333', 'totalQuantity': 115}
# {'_id': "59 rue de l'Abbaye", 'totalQuantity': 98}
# {'_id': 'Av. del Libertador 900', 'totalQuantity': 92}
# {'_id': 'Gran Vía, 1', 'totalQuantity': 91}
# {'_id': '722 DaVinci Blvd.', 'totalQuantity': 89}
# {'_id': 'Berkeley Gardens 12  Brewery', 'totalQuantity': 87}
# {'_id': "67, avenue de l'Europe", 'totalQuantity': 83}
# {'_id': '67, rue des Cinquante Otages', 'totalQuantity': 80}
# {'_id': '54, rue Royale', 'totalQuantity': 69}
# {'_id': 'Avda. de la Constitución 2222', 'totalQuantity': 63}
# {'_id': '2319 Elm St.', 'totalQuantity': 62}
# {'_id': '55 Grizzly Peak Rd.', 'totalQuantity': 59}
# {'_id': 'Via Monte Bianco 34', 'totalQuantity': 54}
# {'_id': '25, rue Lauriston', 'totalQuantity': 48}
# {'_id': '89 Jefferson Way Suite 2', 'totalQuantity': 46}
# {'_id': 'Rambla de Cataluña, 23', 'totalQuantity': 42}
# {'_id': '5ª Ave. Los Palos Grandes', 'totalQuantity': 34}
# {'_id': 'South House 300 Queensbridge', 'totalQuantity': 30}
# {'_id': '12 Orchestra Terrace', 'totalQuantity': 20}
# {'_id': 'Sierras de Granada 9993', 'totalQuantity': 11}

# %%
products_with_total_units = collection.aggregate([
    {
        '$addFields': {
            'totalUnits': {
                '$sum': [
                    '$UnitsInStock', '$UnitsOnOrder'
                ]
            }
        }
    }
])

# %%
new_collection = database["ProductsWithTotalUnits"]

# %%
new_collection.delete_many({})
# Out:
# DeleteResult({'n': 830, 'electionId': ObjectId('7fffffff00000000000001eb'), 'opTime': {'ts': Timestamp(1739178096, 88), 't': 491}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1739178096, 88), 'signature': {'hash': b'\xac\xecu\x1b\x88nT=\t=.\xedS\t\xd6\xae\t\x1fn]', 'keyId': 7416074533414633485}}, 'operationTime': Timestamp(1739178096, 88)}, acknowledged=True)

# %%
new_collection.insert_many(products_with_total_units)
# Out:
# InsertManyResult([ObjectId('67a47884acc37b5ba789ba62'), ObjectId('67a47884acc37b5ba789ba63'), ObjectId('67a47884acc37b5ba789ba64'), ObjectId('67a47884acc37b5ba789ba65'), ObjectId('67a47884acc37b5ba789ba66'), ObjectId('67a47884acc37b5ba789ba67'), ObjectId('67a47884acc37b5ba789ba68'), ObjectId('67a47884acc37b5ba789ba69'), ObjectId('67a47884acc37b5ba789ba6a'), ObjectId('67a47884acc37b5ba789ba6b'), ObjectId('67a47884acc37b5ba789ba6c'), ObjectId('67a47884acc37b5ba789ba6d'), ObjectId('67a47884acc37b5ba789ba6e'), ObjectId('67a47884acc37b5ba789ba6f'), ObjectId('67a47884acc37b5ba789ba70'), ObjectId('67a47884acc37b5ba789ba71'), ObjectId('67a47884acc37b5ba789ba72'), ObjectId('67a47884acc37b5ba789ba73'), ObjectId('67a47884acc37b5ba789ba74'), ObjectId('67a47884acc37b5ba789ba75'), ObjectId('67a47884acc37b5ba789ba76'), ObjectId('67a47884acc37b5ba789ba77'), ObjectId('67a47884acc37b5ba789ba78'), ObjectId('67a47884acc37b5ba789ba79'), ObjectId('67a47884acc37b5ba789ba7a'), ObjectId('67a47884acc37b5ba789ba7b'), ObjectId('67a47884acc37b5ba789ba7c'), ObjectId('67a47884acc37b5ba789ba7d'), ObjectId('67a47884acc37b5ba789ba7e'), ObjectId('67a47884acc37b5ba789ba7f'), ObjectId('67a47884acc37b5ba789ba80'), ObjectId('67a47884acc37b5ba789ba81'), ObjectId('67a47884acc37b5ba789ba82'), ObjectId('67a47884acc37b5ba789ba83'), ObjectId('67a47884acc37b5ba789ba84'), ObjectId('67a47884acc37b5ba789ba85'), ObjectId('67a47884acc37b5ba789ba86'), ObjectId('67a47884acc37b5ba789ba87'), ObjectId('67a47884acc37b5ba789ba88'), ObjectId('67a47884acc37b5ba789ba89'), ObjectId('67a47884acc37b5ba789ba8a'), ObjectId('67a47884acc37b5ba789ba8b'), ObjectId('67a47884acc37b5ba789ba8c'), ObjectId('67a47884acc37b5ba789ba8d'), ObjectId('67a47884acc37b5ba789ba8e'), ObjectId('67a47884acc37b5ba789ba8f'), ObjectId('67a47884acc37b5ba789ba90'), ObjectId('67a47884acc37b5ba789ba91'), ObjectId('67a47884acc37b5ba789ba92'), ObjectId('67a47884acc37b5ba789ba93'), ObjectId('67a47884acc37b5ba789ba94'), ObjectId('67a47884acc37b5ba789ba95'), ObjectId('67a47884acc37b5ba789ba96'), ObjectId('67a47884acc37b5ba789ba97'), ObjectId('67a47884acc37b5ba789ba98'), ObjectId('67a47884acc37b5ba789ba99'), ObjectId('67a47884acc37b5ba789ba9a'), ObjectId('67a47884acc37b5ba789ba9b'), ObjectId('67a47884acc37b5ba789ba9c'), ObjectId('67a47884acc37b5ba789ba9d'), ObjectId('67a47884acc37b5ba789ba9e'), ObjectId('67a47884acc37b5ba789ba9f'), ObjectId('67a47884acc37b5ba789baa0'), ObjectId('67a47884acc37b5ba789baa1'), ObjectId('67a47884acc37b5ba789baa2'), ObjectId('67a47884acc37b5ba789baa3'), ObjectId('67a47884acc37b5ba789baa4'), ObjectId('67a47884acc37b5ba789baa5'), ObjectId('67a47884acc37b5ba789baa6'), ObjectId('67a47884acc37b5ba789baa7'), ObjectId('67a47884acc37b5ba789baa8'), ObjectId('67a47884acc37b5ba789baa9'), ObjectId('67a47884acc37b5ba789baaa'), ObjectId('67a47884acc37b5ba789baab'), ObjectId('67a47884acc37b5ba789baac'), ObjectId('67a47884acc37b5ba789baad'), ObjectId('67a47884acc37b5ba789baae'), ObjectId('67a47884acc37b5ba789baaf'), ObjectId('67a47884acc37b5ba789bab0'), ObjectId('67a47884acc37b5ba789bab1'), ObjectId('67a47884acc37b5ba789bab2'), ObjectId('67a47884acc37b5ba789bab3'), ObjectId('67a47884acc37b5ba789bab4'), ObjectId('67a47884acc37b5ba789bab5'), ObjectId('67a47884acc37b5ba789bab6'), ObjectId('67a47884acc37b5ba789bab7'), ObjectId('67a47884acc37b5ba789bab8'), ObjectId('67a47884acc37b5ba789bab9'), ObjectId('67a47884acc37b5ba789baba'), ObjectId('67a47884acc37b5ba789babb'), ObjectId('67a47884acc37b5ba789babc'), ObjectId('67a47884acc37b5ba789babd'), ObjectId('67a47884acc37b5ba789babe'), ObjectId('67a47884acc37b5ba789babf'), ObjectId('67a47884acc37b5ba789bac0'), ObjectId('67a47884acc37b5ba789bac1'), ObjectId('67a47884acc37b5ba789bac2'), ObjectId('67a47884acc37b5ba789bac3'), ObjectId('67a47884acc37b5ba789bac4'), ObjectId('67a47884acc37b5ba789bac5'), ObjectId('67a47884acc37b5ba789bac6'), ObjectId('67a47884acc37b5ba789bac7'), ObjectId('67a47884acc37b5ba789bac8'), ObjectId('67a47884acc37b5ba789bac9'), ObjectId('67a47884acc37b5ba789 ...

# %%
more_than_20 = new_collection.find({"totalUnits": {"$gt": 10}})

# %%
[res for res in more_than_20]
# Out:
# []
